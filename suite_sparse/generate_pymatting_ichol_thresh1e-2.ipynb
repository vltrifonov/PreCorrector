# %%
import os
import time
import pymatting
import numpy as np
from scipy import sparse

# %%
kapset = [
    'bodyy6','bcsstk18','bcsstk25','cvxbqp1','bcsstk17','gridgena',
    'apache1','Pres_Poisson','G2_circuit','olafu','gyro_k','msc23052',
    'bcsstk36','msc10848','raefsky4','cfd1','oilpan','vanbody','ct20stif',
    'nasasrb','cfd2','shipsec8','shipsec1','Dubcova3','parabolic_fem',
    's3dkt3m2','smt','ship_003','ship_001','cant','offshore','pdb1HYS',
    's3dkq4m2','thread', 'shipsec5',
    'apache2','ecology2','tmt_sym','boneS01',
    'consph','bmw7st_1','G3_circuit','x104','thermal2','m_t1','hood','crankseg_1',
    'bmwcra_1','pwtk','crankseg_2','nd12k','af_shell7','msdoor','F1','nd24k','ldoor'
]
path_load = '/mnt/local/data/vtrifonov/susbet_SuiteSparse/scipy_sparse'
path_save = '/mnt/local/data/vtrifonov/susbet_SuiteSparse/pymatting_ichol_thresh1e-2'

# %%
def jacobi_symm_scaling(A):
    D = sparse.diags(-1 / (np.sqrt(A.diagonal()) + 1e-10))
    return D @ A @ D

# %%
generation_time = {}
for i, name in enumerate(kapset):
    A = sparse.load_npz(os.path.join(path_load, name+'.npz')).tocsr()
    
    A_s = jacobi_symm_scaling(A)
    try:
        s_ = time.perf_counter()
        L = pymatting.ichol(A_s, discard_threshold=1e-2).L
        generation_time[name] = time.perf_counter() - s_
        
        sparse.save_npz(os.path.join(path_save, name+'_ichol_pymatting.npz'), L)
        print(f'\n   {i+1}. {name.upper()} IS DONE. TIME IS {generation_time[name]:.4f} \n')
    except Exception as e:     
        generation_time[name] = -42
        print(f'\n   !!! {i+1}. {name.upper()} FAILED !!!')
        print(e, end='\n\n')
# Out:
#    1. BODYY6 IS DONE. TIME IS 0.0215
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-04
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-03
# Try decreasing discard_threshold or start with a larger shift
#
#
#    2. BCSSTK18 IS DONE. TIME IS 0.0372
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-04
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-03
# Try decreasing discard_threshold or start with a larger shift
#
#
#    3. BCSSTK25 IS DONE. TIME IS 0.0431
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-04
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-03
# Try decreasing discard_threshold or start with a larger shift
#
#
#    4. CVXBQP1 IS DONE. TIME IS 0.3352
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-04
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-03
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-02
# Try decreasing discard_threshold or start with a larger shift
#
#
#    5. BCSSTK17 IS DONE. TIME IS 0.0533
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-04
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-03
# Try decreasing discard_threshold or start with a larger shift
#
#
#    6. GRIDGENA IS DONE. TIME IS 0.0609
#
#
#    7. APACHE1 IS DONE. TIME IS 0.0564
#
#
#    8. PRES_POISSON IS DONE. TIME IS 0.0629
#
#
#    9. G2_CIRCUIT IS DONE. TIME IS 0.1073
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-04
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-03
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-02
# Try decreasing discard_threshold or start with a larger shift
#
#
#    10. OLAFU IS DONE. TIME IS 0.0750
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-04
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-03
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-02
# Try decreasing discard_threshold or start with a larger shift
#
#
#    11. GYRO_K IS DONE. TIME IS 0.1934
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-04
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-03
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-02
# Try decreasing discard_threshold or start with a larger shift
#
#
#    12. MSC23052 IS DONE. TIME IS 0.1896
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-04
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-03
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-02
# Try decreasing discard_threshold or start with a larger shift
#
#
#    13. BCSSTK36 IS DONE. TIME IS 0.1394
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-04
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-03
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-02
# Try decreasing discard_threshold or start with a larger shift
#
#
#    14. MSC10848 IS DONE. TIME IS 0.2633
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-04
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-03
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-02
# Try decreasing discard_threshold or start with a larger shift
#
#
#    15. RAEFSKY4 IS DONE. TIME IS 0.3830
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-04
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-03
# Try decreasing discard_threshold or start with a larger shift
#
#
#    16. CFD1 IS DONE. TIME IS 0.4438
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-04
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-03
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-02
# Try decreasing discard_threshold or start with a larger shift
#
#
#    17. OILPAN IS DONE. TIME IS 0.2433
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-04
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-03
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-02
# Try decreasing discard_threshold or start with a larger shift
#
#
#    18. VANBODY IS DONE. TIME IS 0.2200
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-04
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-03
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-02
# Try decreasing discard_threshold or start with a larger shift
#
#
#    19. CT20STIF IS DONE. TIME IS 0.5296
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-04
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-03
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-02
# Try decreasing discard_threshold or start with a larger shift
#
#
#    20. NASASRB IS DONE. TIME IS 0.1973
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-04
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-03
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-02
# Try decreasing discard_threshold or start with a larger shift
#
#
#    21. CFD2 IS DONE. TIME IS 1.0033
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-04
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-03
# Try decreasing discard_threshold or start with a larger shift
#
#
#    22. SHIPSEC8 IS DONE. TIME IS 0.4786
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-04
# Try decreasing discard_threshold or start with a larger shift
#
#
#    23. SHIPSEC1 IS DONE. TIME IS 0.6743
#
#
#    24. DUBCOVA3 IS DONE. TIME IS 0.6205
#
#
#    25. PARABOLIC_FEM IS DONE. TIME IS 0.5047
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-04
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-03
# Try decreasing discard_threshold or start with a larger shift
#
#
#    26. S3DKT3M2 IS DONE. TIME IS 0.3048
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-04
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-03
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-02
# Try decreasing discard_threshold or start with a larger shift
#
#
#    27. SMT IS DONE. TIME IS 1.0269
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-04
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-03
# Try decreasing discard_threshold or start with a larger shift
#
#
#    28. SHIP_003 IS DONE. TIME IS 0.7153
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-04
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-03
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-02
# Try decreasing discard_threshold or start with a larger shift
#
#
#    29. SHIP_001 IS DONE. TIME IS 0.8206
#
#
#    30. CANT IS DONE. TIME IS 0.3665
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-04
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-03
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-02
# Try decreasing discard_threshold or start with a larger shift
#
#
#    31. OFFSHORE IS DONE. TIME IS 0.9406
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-04
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-03
# Try decreasing discard_threshold or start with a larger shift
#
#
#    32. PDB1HYS IS DONE. TIME IS 0.4841
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-04
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-03
# Try decreasing discard_threshold or start with a larger shift
#
#
#    33. S3DKQ4M2 IS DONE. TIME IS 0.3391
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-04
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-03
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-02
# Try decreasing discard_threshold or start with a larger shift
#
#
#    34. THREAD IS DONE. TIME IS 0.5107
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-04
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-03
# Try decreasing discard_threshold or start with a larger shift
#
#
#    35. SHIPSEC5 IS DONE. TIME IS 0.5655
#
#
#    36. APACHE2 IS DONE. TIME IS 0.5403
#
#
#    37. ECOLOGY2 IS DONE. TIME IS 0.8030
#
#
#    38. TMT_SYM IS DONE. TIME IS 0.5859
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-04
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-03
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-02
# Try decreasing discard_threshold or start with a larger shift
#
#
#    39. BONES01 IS DONE. TIME IS 1.3564
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-04
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-03
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-02
# Try decreasing discard_threshold or start with a larger shift
#
#
#    40. CONSPH IS DONE. TIME IS 3.0785
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-04
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-03
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-02
# Try decreasing discard_threshold or start with a larger shift
#
#
#    41. BMW7ST_1 IS DONE. TIME IS 0.8625
#
#
#    42. G3_CIRCUIT IS DONE. TIME IS 1.1835
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-04
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-03
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-02
# Try decreasing discard_threshold or start with a larger shift
#
#
#    43. X104 IS DONE. TIME IS 0.8284
#
#
#    44. THERMAL2 IS DONE. TIME IS 1.4788
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-04
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-03
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-02
# Try decreasing discard_threshold or start with a larger shift
#
#
#    45. M_T1 IS DONE. TIME IS 0.9453
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-04
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-03
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-02
# Try decreasing discard_threshold or start with a larger shift
#
#
#    46. HOOD IS DONE. TIME IS 2.8535
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-04
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-03
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-02
# Try decreasing discard_threshold or start with a larger shift
#
#
#    47. CRANKSEG_1 IS DONE. TIME IS 10.0797
#
#
#    48. BMWCRA_1 IS DONE. TIME IS 1.4782
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-04
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-03
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-02
# Try decreasing discard_threshold or start with a larger shift
#
#
#    49. PWTK IS DONE. TIME IS 0.9818
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-04
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-03
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-02
# Try decreasing discard_threshold or start with a larger shift
#
#
#    50. CRANKSEG_2 IS DONE. TIME IS 18.7376
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-04
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-03
# Try decreasing discard_threshold or start with a larger shift
#
#
#    51. ND12K IS DONE. TIME IS 0.3825
#
#
#    52. AF_SHELL7 IS DONE. TIME IS 1.1832
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-04
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-03
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-02
# Try decreasing discard_threshold or start with a larger shift
#
#
#    53. MSDOOR IS DONE. TIME IS 4.7998
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-04
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-03
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-02
# Try decreasing discard_threshold or start with a larger shift
#
#
#    54. F1 IS DONE. TIME IS 26.4539
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-04
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-03
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-02
# Try decreasing discard_threshold or start with a larger shift
#
#
#    55. ND24K IS DONE. TIME IS 1.1316
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-04
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-03
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-02
#     shift = 1.000000e-02
# Try decreasing discard_threshold or start with a larger shift
#
#
#    56. LDOOR IS DONE. TIME IS 9.6446

# %%
2+3
# Out:
# 5

# %%
len(kapset)
# Out:
# 56

# %%
len(generation_time)
# Out:
# 56

# %%
import cloudpickle
with open(os.path.join(path_save, 'time_generation.pkl'), 'wb') as f:
    cloudpickle.dump(generation_time, f)

generation_time
# Out:
# {'bodyy6': 0.021537616848945618,
#  'bcsstk18': 0.037194808945059776,
#  'bcsstk25': 0.043139614164829254,
#  'cvxbqp1': 0.33519030176103115,
#  'bcsstk17': 0.05334976501762867,
#  'gridgena': 0.0609433650970459,
#  'apache1': 0.05637752823531628,
#  'Pres_Poisson': 0.06293664872646332,
#  'G2_circuit': 0.10731610096991062,
#  'olafu': 0.07503044977784157,
#  'gyro_k': 0.19343673810362816,
#  'msc23052': 0.18959275633096695,
#  'bcsstk36': 0.13939957320690155,
#  'msc10848': 0.2633082941174507,
#  'raefsky4': 0.3829974830150604,
#  'cfd1': 0.44376192055642605,
#  'oilpan': 0.24332256242632866,
#  'vanbody': 0.22002582252025604,
#  'ct20stif': 0.5296416655182838,
#  'nasasrb': 0.19728155620396137,
#  'cfd2': 1.003252336755395,
#  'shipsec8': 0.47859024815261364,
#  'shipsec1': 0.6742647048085928,
#  'Dubcova3': 0.6205205898731947,
#  'parabolic_fem': 0.5046918801963329,
#  's3dkt3m2': 0.30475810915231705,
#  'smt': 1.0269227307289839,
#  'ship_003': 0.7152509316802025,
#  'ship_001': 0.8205839265137911,
#  'cant': 0.3665004838258028,
#  'offshore': 0.9406249634921551,
#  'pdb1HYS': 0.4840912036597729,
#  's3dkq4m2': 0.3390604555606842,
#  'thread': 0.5106678530573845,
#  'shipsec5': 0.5655173826962709,
#  'apache2': 0.540308840572834,
#  'ecology2': 0.802968043833971,
#  'tmt_sym': 0.5859209280461073,
#  'boneS01': 1.3563959002494812,
#  'consph': 3.0784684009850025,
#  'bmw7st_1': 0.8625275567173958,
#  'G3_circuit': 1.1835353709757328,
#  'x104': 0.828401168808341,
#  'thermal2': 1.4787743650376797,
#  'm_t1': 0.9452994577586651,
#  'hood': 2.85348598100245,
#  'crankseg_1': 10.07969743013382,
#  'bmwcra_1': 1.4781511258333921,
#  'pwtk': 0.9818182215094566,
#  'crankseg_2': 18.737562162801623,
#  'nd12k': 0.3825311157852411,
#  'af_shell7': 1.1831918936222792,
#  'msdoor': 4.79979932308197,
#  'F1': 26.453861778602004,
#  'nd24k': 1.1315870434045792,
#  'ldoor': 9.644604217261076}
