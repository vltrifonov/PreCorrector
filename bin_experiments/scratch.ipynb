# %%
import numpy as np

# %%
new_ilu0_32 = 1.5 * 1e-3 #0.001537
new_ict_32 = 1.4 * 1e-3 #0.001372

new_ilu0_64 = 1.8 * 1e-3 #0.001777
new_ict_64 = 1.4 * 1e-3 #0.001432

new_ilu0_128 = 1.5 * 1e-3 #0.001478
new_ict_128 = 1.6 * 1e-3 #0.001598

# %%
# Poisson
# old_ilu0_32 = 8.6 * 1e-2
# old_ict_32 = 8.6 * 1e-2

# old_ilu0_64 = 8.6 * 1e-2
# old_ict_64 = 8.7 * 1e-2

# old_ilu0_128 = 8.6 * 1e-2
# old_ict_128 = 8.9 * 1e-2

# Classical IC time 
poisson_32_ic0 = 8.2 * 1e-5
poisson_32_ict1 = 3 * 1e-4

poisson_64_ic0 = 1.9 * 1e-4
poisson_64_ict1 = 1.1 * 1e-3

poisson_128_ic0 = 4.6 * 1e-4
poisson_128_ict1 = 3.3 * 1e-3
#--------------------------------------------------
ilu0_32 = np.array([0.031848, 0.040752, 0.049400])
ict_32 = np.array([0.027015, 0.034170, 0.040980])

ilu0_64 = np.array([0.090553, 0.116460, 0.140097])
ict_64 = np.array([0.068208, 0.087131, 0.105499])

ilu0_128 = np.array([0.389401, 0.495402, 0.591816])
ict_128 = np.array([0.292788, 0.376259, 0.452043])
#--------------------------------------------------
print('32 ilu0\n ', np.round(ilu0_32 + new_ilu0_32 + poisson_32_ic0, 3), end='\n\n')
print('32 ict\n ', np.round(ict_32 + new_ict_32 + poisson_32_ict1, 3), end='\n\n')

print('64 ilu0\n ', np.round(ilu0_64 + new_ilu0_64 + poisson_64_ic0, 3), end='\n\n')
print('64 ict\n ', np.round(ict_64 + new_ict_64 + poisson_64_ict1, 3), end='\n\n')

print('128 ilu0\n ', np.round(ilu0_128 + new_ilu0_128 + poisson_128_ic0, 3), end='\n\n')
print('128 ict\n ', np.round(ict_128 + new_ict_128 + poisson_128_ict1, 3), end='\n\n')
# Out:
# 32 ilu0
#   [0.033 0.042 0.051]
#
# 32 ict
#   [0.029 0.036 0.043]
#
# 64 ilu0
#   [0.093 0.118 0.142]
#
# 64 ict
#   [0.071 0.09  0.108]
#
# 128 ilu0
#   [0.391 0.497 0.594]
#
# 128 ict
#   [0.298 0.381 0.457]

# %%
print(poisson_32_ic0 + new_ilu0_32)
print(poisson_32_ict1 + new_ict_32)
print(poisson_64_ic0 + new_ilu0_64)
print(poisson_64_ict1 + new_ict_64)
print(poisson_128_ic0 + new_ilu0_128)
print(poisson_128_ict1 + new_ict_128)
# Out:
# 0.001582
# 0.0017000000000000001
# 0.00199
# 0.0025
# 0.00196
# 0.0049

# %%
# div-k-grad 0.1
# old_ilu0_32 = 8.6 * 1e-2
# old_ict_32 = 8.6 * 1e-2

# old_ilu0_64 = 8.6 * 1e-2
# old_ict_64 = 8.6 * 1e-2

# old_ilu0_128 = 8.6 * 1e-2
# old_ict_128 = 8.9 * 1e-2


# Classical IC time 
dkg_01_32_ic0 = 7.2 * 1e-5
dkg_01_32_ict1 = 2.6 * 1e-4

dkg_01_64_ic0 = 1.6 * 1e-4
dkg_01_64_ict1 = 8.6 * 1e-4

dkg_01_128_ic0 = 4.6 * 1e-4
dkg_01_128_ict1 = 3.4 * 1e-3
#--------------------------------------------------
ilu0_32 = np.array([0.038681, 0.048762, 0.058338])
ict_32 = np.array([0.031736, 0.039575, 0.047312])

ilu0_64 = np.array([0.097238, 0.124506, 0.149410])
ict_64 = np.array([0.085344, 0.109352, 0.131760])

ilu0_128 = np.array([0.422728, 0.535947, 0.640906])
ict_128 = np.array([0.362497, 0.463854, 0.554940])
#--------------------------------------------------
print('32 ilu0\n ', np.round(ilu0_32 + new_ilu0_32 + dkg_01_32_ic0, 3), end='\n\n')
print('32 ict\n ', np.round(ict_32 + new_ict_32 + dkg_01_32_ict1, 3), end='\n\n')

print('64 ilu0\n ', np.round(ilu0_64 + new_ilu0_64 + dkg_01_64_ic0, 3), end='\n\n')
print('64 ict\n ', np.round(ict_64 + new_ict_64 + dkg_01_64_ict1, 3), end='\n\n')

print('128 ilu0\n ', np.round(ilu0_128 + new_ilu0_128 + dkg_01_128_ic0, 3), end='\n\n')
print('128 ict\n ', np.round(ict_128 + new_ict_128 + dkg_01_128_ict1, 3), end='\n\n')
# Out:
# 32 ilu0
#   [0.04 0.05 0.06]
#
# 32 ict
#   [0.033 0.041 0.049]
#
# 64 ilu0
#   [0.099 0.126 0.151]
#
# 64 ict
#   [0.088 0.112 0.134]
#
# 128 ilu0
#   [0.425 0.538 0.643]
#
# 128 ict
#   [0.367 0.469 0.56 ]

# %%
print(dkg_01_32_ic0 + new_ilu0_32)
print(dkg_01_32_ict1 + new_ict_32)
print(dkg_01_64_ic0 + new_ilu0_64)
print(dkg_01_64_ict1 + new_ict_64)
print(dkg_01_128_ic0 + new_ilu0_128)
print(dkg_01_128_ict1 + new_ict_128)
# Out:
# 0.001572
# 0.00166
# 0.0019600000000000004
# 0.00226
# 0.00196
# 0.005

# %%
# div-k-grad 0.5
# old_ilu0_32 = 8.6 * 1e-2
# old_ict_32 = 8.6 * 1e-2

# old_ilu0_64 = 8.6 * 1e-2
# old_ict_64 = 8.6 * 1e-2

# old_ilu0_128 = 8.6 * 1e-2
# old_ict_128 = 8.9 * 1e-2


# Classical IC time 
dkg_05_32_ic0 = 7.2 * 1e-5
dkg_05_32_ict1 = 2.6 * 1e-4

dkg_05_64_ic0 = 1.6 * 1e-4
dkg_05_64_ict1 = 9.6 * 1e-4

dkg_05_128_ic0 = 4.7 * 1e-4
dkg_05_128_ict1 = 3.4 * 1e-3
#--------------------------------------------------
ilu0_32 = np.array([0.039891, 0.050200, 0.059898])
ict_32 = np.array([0.029212, 0.036586, 0.043618])

ilu0_64 = np.array([0.096037, 0.121728, 0.146091])
ict_64 = np.array([0.082474, 0.104631, 0.125997])

ilu0_128 = np.array([0.496078, 0.626438, 0.746045])
ict_128 = np.array([0.339192, 0.432151, 0.519508])
#--------------------------------------------------
print('32 ilu0\n ', np.round(ilu0_32 + new_ilu0_32 + dkg_05_32_ic0, 3), end='\n\n')
print('32 ict\n ', np.round(ict_32 + new_ict_32 + dkg_05_32_ict1, 3), end='\n\n')

print('64 ilu0\n ', np.round(ilu0_64 + new_ilu0_64 + dkg_05_64_ic0, 3), end='\n\n')
print('64 ict\n ', np.round(ict_64 + new_ict_64 + dkg_05_64_ict1, 3), end='\n\n')

print('128 ilu0\n ', np.round(ilu0_128 + new_ilu0_128 + dkg_05_128_ic0, 3), end='\n\n')
print('128 ict\n ', np.round(ict_128 + new_ict_128 + dkg_05_128_ict1, 3), end='\n\n')
# Out:
# 32 ilu0
#   [0.041 0.052 0.061]
#
# 32 ict
#   [0.031 0.038 0.045]
#
# 64 ilu0
#   [0.098 0.124 0.148]
#
# 64 ict
#   [0.085 0.107 0.128]
#
# 128 ilu0
#   [0.498 0.628 0.748]
#
# 128 ict
#   [0.344 0.437 0.525]

# %%
print(dkg_05_32_ic0 + new_ilu0_32)
print(dkg_05_32_ict1 + new_ict_32)
print(dkg_05_64_ic0 + new_ilu0_64)
print(dkg_05_64_ict1 + new_ict_64)
print(dkg_05_128_ic0 + new_ilu0_128)
print(dkg_05_128_ict1 + new_ict_128)
# Out:
# 0.001572
# 0.00166
# 0.0019600000000000004
# 0.00236
# 0.00197
# 0.005

# %%
# div-k-grad 0.7
# old_ilu0_32 = 8.6 * 1e-2
# old_ict_32 = 8.6 * 1e-2

# old_ilu0_64 = 8.6 * 1e-2
# old_ict_64 = 8.6 * 1e-2

# old_ilu0_128 = 8.6 * 1e-2
# old_ict_128 = 8.9 * 1e-2



# Classical IC time 
dkg_07_32_ic0 = 7 * 1e-5
dkg_07_32_ict1 = 2.6 * 1e-4

dkg_07_64_ic0 = 1.6 * 1e-4
dkg_07_64_ict1 = 8.7 * 1e-4

dkg_07_128_ic0 = 5.1 * 1e-4
dkg_07_128_ict1 = 3.8 * 1e-3
#--------------------------------------------------
ilu0_32 = np.array([0.042243, 0.053333, 0.063792])
ict_32 = np.array([0.033898, 0.042391, 0.050246])

ilu0_64 = np.array([0.110281, 0.139506, 0.167850])
ict_64 = np.array([0.088502, 0.112811, 0.135704])

ilu0_128 = np.array([0.568681, 0.717592, 0.856984])
ict_128 = np.array([0.464470, 0.587898, 0.702495])
#--------------------------------------------------
print('32 ilu0\n ', np.round(ilu0_32  + new_ilu0_32 + dkg_07_32_ic0, 3), end='\n\n')
print('32 ict\n ', np.round(ict_32 + new_ict_32 + dkg_07_32_ict1, 3), end='\n\n')

print('64 ilu0\n ', np.round(ilu0_64 + new_ilu0_64 + dkg_07_64_ic0, 3), end='\n\n')
print('64 ict\n ', np.round(ict_64 + new_ict_64 + dkg_07_64_ict1, 3), end='\n\n')

print('128 ilu0\n ', np.round(ilu0_128 + new_ilu0_128 + dkg_07_128_ic0, 3), end='\n\n')
print('128 ict\n ', np.round(ict_128 + new_ict_128 + dkg_07_128_ict1, 3), end='\n\n')
# Out:
# 32 ilu0
#   [0.044 0.055 0.065]
#
# 32 ict
#   [0.036 0.044 0.052]
#
# 64 ilu0
#   [0.112 0.141 0.17 ]
#
# 64 ict
#   [0.091 0.115 0.138]
#
# 128 ilu0
#   [0.571 0.72  0.859]
#
# 128 ict
#   [0.47  0.593 0.708]

# %%
print(dkg_07_32_ic0 + new_ilu0_32)
print(dkg_07_32_ict1 + new_ict_32)
print(dkg_07_64_ic0 + new_ilu0_64)
print(dkg_07_64_ict1 + new_ict_64)
print(dkg_07_128_ic0 + new_ilu0_128)
print(dkg_07_128_ict1 + new_ict_128)
# Out:
# 0.00157
# 0.00166
# 0.0019600000000000004
# 0.00227
# 0.00201
# 0.0054

# %%
# PrecNet
inf_time = 2.5 * 1e-3

poisson_32 = np.array([0.036246, 0.045482, 0.053391])
poisson_64 = np.array([0.103085, 0.128519, 0.151142])
poisson_128 = np.array([0.427795, 0.534954, 0.642025])

# variance = 0.1
dkg_32 = np.array([0.085722, 0.110034, 0.132325])

print('Poisson 32\n ', np.round(poisson_32 + inf_time, 3), end='\n\n')
print('Poisson 64\n ', np.round(poisson_64 + inf_time, 3), end='\n\n')
print('Poisson 128\n ', np.round(poisson_128 + inf_time, 3), end='\n\n')
print('Div-k-grad 32\n ', np.round(dkg_32 + inf_time, 3), end='\n\n')
# Out:
# Poisson 32
#   [0.039 0.048 0.056]
#
# Poisson 64
#   [0.106 0.131 0.154]
#
# Poisson 128
#   [0.43  0.537 0.645]
#
# Div-k-grad 32
#   [0.088 0.113 0.135]

# %%
print(dkg_01_32_ic0 + inf_time)
print(poisson_32_ic0 + inf_time)
print(poisson_64_ic0 + inf_time)
print(poisson_128_ic0 + inf_time)
# Out:
# 0.002572
# 0.002582
# 0.00269
# 0.00296

# %%
inter = b.intersection(names_)
union = b.union(names_)

len(inter), len(union)
# Out:
# (50, 83)

# %%
names_ - b
# Out:
# {'dubcova3', 'f1', 'g2_circuit', 'g3_circuit', 'pdb1hys', 'pres_poisson'}

# %%
names_.intersection(names_ - b)
# Out:
# {'dubcova3', 'f1', 'g2_circuit', 'g3_circuit', 'pdb1hys', 'pres_poisson'}

# %%
'Dubcova3', 'F1', 'G2_circuit', 'G3_circuit', 'pdb1HYS', 'Rres_Poisson'

# %%
import parafields
import matplotlib.pyplot as plt
import numpy as np

# %%
covariences = [
    'separableExponential',
    'matern32',
    'matern52',
    'gaussian',
    'spherical',
    'cauchy',
    'generalizedCauchy',
    'cubic',
    'dampedOscillation',
    'exponential',
]

# %%
fig, axes = plt.subplots(2, 5, figsize=(17, 7))
axes = axes.flatten()

for i, cov_model in enumerate(covariences):
    contrast = 0
    while contrast < 200 or contrast > 300:
        field = parafields.generate_field(cells=[128+1, 128+1], covariance=cov_model, variance=0.5)
        k = field.evaluate()
        contrast = np.exp(k.max() - k.min())
    axes[i].imshow(k)
    axes[i].set_title(f'{cov_model}\ncontrast={contrast:.0f}')
    axes[i].set_axis_off()
    
# plt.tight_layout()

# %%
field = parafields.generate_field(
    cells=(129, 129),
    covariance="exponential",
    variance=1.0,
    anisotropy="axiparallel",
    corrLength=[0.05, 0.2],
)
k = field.evaluate()
contrast = np.exp(k.max() - k.min())

plt.imshow(k)
plt.axis(False)
plt.title(f'contrast = {contrast}');

# %%
fig, axes = plt.subplots(2, 5, figsize=(17, 7))
axes = axes.flatten()

for i, cov_model in enumerate(covariences):
    field = parafields.generate_field(cells=[128+1, 128+1], covariance=cov_model, variance=0.7)
    k = np.ones(1)
    k = field.evaluate()
    contrast = np.exp(k.max() - k.min())
    axes[i].imshow(k)
    axes[i].set_title(f'{cov_model}\ncontrast={contrast:.0f}')
    axes[i].set_axis_off()

# %%
f = parafields.generate_field(cells=[128+1, 128+1], covariance='whiteNoise', variance=0.5)
k = f.evaluate()
print(np.exp(k.max() - k.min()))
f
# Out:
# 375.748400722939

# %%
covariance 

`exponential` (default choice)
    * `gammaExponential` (requires parameter `gammaExp`)
    * `separableExponential`
    * `matern` (requires parameter `maternNu`)
    * `matern32`
    * `matern52`
    * `gaussian`
    * `spherical`
    * `cauchy`
    * `generalizedCauchy`
    * `cubic`
    * `dampedOscillation`
    * `whiteNoise`
    
anisotropy
* `none` for an isotropic field
    * `axiparallel`
    * `geometric`

# %%
import warnings
import sys
import os

warnings.filterwarnings('ignore')
os.environ["CUDA_VISIBLE_DEVICES"] = ''
os.environ['XLA_PYTHON_CLIENT_MEM_FRACTION'] = '.95'
os.environ['JAX_ENABLE_X64'] = 'True'
sys.path.append('/mnt/local/data/vtrifonov/prec-learning-Notay-loss/')

# %%
import jax.numpy as jnp
from jax import random
from jax.experimental import sparse as jsparse
from jax.lax import scan

def сurrentConjGrad(A, rhs, N_iter, prec_func=None, eps=1e-30, seed=42):
    '''Preconditioned Conjugate Gradient'''
    apply_prec = prec_func if prec_func else lambda res, *args: res
    samples = rhs.shape[0]
    n = rhs.shape[1]

    X = jnp.zeros([samples, n, N_iter+1])
    R = jnp.zeros([samples, n, N_iter+1])
    Z = jnp.zeros([samples, n])
    P = jnp.zeros([samples, n])

    X = X.at[:, :, 0].set(random.normal(random.PRNGKey(seed), [samples, n]))
    R = R.at[:, :, 0].set(rhs - jsparse.bcoo_dot_general(A, X[:, :, 0], dimension_numbers=((2,1), (0,0))))
    Z = apply_prec(res=R[:, :, 0])
    P = Z

    w = jsparse.bcoo_dot_general(A, P, dimension_numbers=((2,1), (0,0)))
    alpha = jnp.einsum('bj, bj -> b', R[:, :, 0], Z) / (jnp.einsum('bj, bj -> b', P, w) + eps)
    X = X.at[:, :, 1].set(X[:, :, 0] + jnp.einsum('bj, b -> bj', P, alpha))
    R = R.at[:, :, 1].set(R[:, :, 0] - jnp.einsum('bj, b -> bj', w, alpha))
    
    def cg_body(carry, idx):
        X, R, Z, P = carry

        z_k_plus_1 = apply_prec(res=R[:, :, idx])

        beta = jnp.einsum('bj, bj->b', R[:, :, idx], z_k_plus_1) / (jnp.einsum('bj, bj->b', R[:, :, idx-1], Z) + eps)
        Z = z_k_plus_1
        P = Z + jnp.einsum('b, bj->bj', beta, P)

        w = jsparse.bcoo_dot_general(A, P, dimension_numbers=((2,1), (0,0)))
        alpha = jnp.einsum('bj, bj -> b', R[:, :, idx], Z) / (jnp.einsum('bj, bj -> b', P, w) + eps)

        X = X.at[:, :, idx+1].set(X[:, :, idx] + jnp.einsum('b, bj->bj', alpha, P))
        R = R.at[:, :, idx+1].set(R[:, :, idx] - jnp.einsum('b, bj->bj', alpha, w))
        return (X, R, Z, P), None

    carry_init = (X, R, Z, P)        
    (X, R, _, _), _ = scan(cg_body, carry_init, jnp.arange(1, N_iter))
    return X, R

# %%
import ilupp
from utils import jBCOO_to_scipyCSR
from jax.experimental import sparse as jsparse
plt.set_cmap('binary')

# %%
model_config = {
    'node_enc': {
        'features': [1, 16, 16],
        'N_layers': 2,
        'layer_': ConstantConv1d
    },
    'edge_enc': {
        'features': [1, 16, 16],
        'N_layers': 2,
        'layer_': ConstantConv1d
    },
    'edge_dec': {
        'features': [16, 16, 1],
        'N_layers': 2,
        'layer_': ConstantConv1d
    },
    'mp': {
        'edge_upd': {
            'features': [48, 16, 16],
            'N_layers': 2,
            'layer_': ConstantConv1d
        },
        'node_upd': {
            'features': [32, 16, 16],
            'N_layers': 2,
            'layer_': ConstantConv1d
        },
        'mp_rounds': 5
    }
}

# %%
grid_ls = [8]# [32, 64, 128, 256, 512]
average_over = 100

dt_ls = {}
for grid in grid_ls:
    
    A_train, A_pad_train, b_train, u_exact_train, bi_edges_train = dataset_FD(grid, N_samples=1, seed=42, rhs_distr='random', rhs_offset=0, k_distr='poisson', k_offset=0, lhs_type='fd')
    
    seed = 42
    NodeEncoder = FullyConnectedNet(**model_config['node_enc'], key=random.PRNGKey(seed))
    EdgeEncoder = FullyConnectedNet(**model_config['edge_enc'], key=random.PRNGKey(seed))
    EdgeDecoder = FullyConnectedNet(**model_config['edge_dec'], key=random.PRNGKey(seed))

    mp_rounds = 5
    MessagePass = MessagePassing(
        update_edge_fn = FullyConnectedNet(**model_config['mp']['edge_upd'], key=random.PRNGKey(seed)),    
        update_node_fn = FullyConnectedNet(**model_config['mp']['node_upd'], key=random.PRNGKey(seed)),
        mp_rounds=model_config['mp']['mp_rounds']
    )

    model = PrecNet(NodeEncoder=NodeEncoder, EdgeEncoder=EdgeEncoder, 
                    EdgeDecoder=EdgeDecoder, MessagePass=MessagePass)
    
    err = jnp.linalg.norm(b_train[0, ...] - A_train[0, ...] @ u_exact_train[0, ...], ord=2) / jnp.linalg.norm(b_train[0, ...], ord=2)
    print('grid =', grid, ', |b - Ax| \ |b| =', err.item())
#     dt = 0
#     for _ in range(average_over):
#         s_ = perf_counter()
#         L = vmap(model, in_axes=(0, 0, 0, 0, 0), out_axes=(0))(*direc_graph_from_linear_system_sparse(A_pad_train, b_train)[:-1], bi_edges_train)
#         dt += (perf_counter() - s_)
#     dt_ls[grid] = dt / average_over
# Out:
# grid = 8 , |b - Ax| \ |b| = 2.459880904680731e-16

# %%
plt.rcParams['figure.figsize'] = (15, 15)
a = jBCOO_to_scipyCSR(A_train[0, ...])
l, u = ilupp.ilu0(a)
lu = l @ u
b = lu - a


a_ = a.copy()
a_.data = a_.data * 0 + 1
plt.subplot(1, 3, 1)
plt.imshow(a_.todense())
plt.title('A')

lu_ = lu.copy()
lu_.data = lu_.data * 0 + 1
plt.subplot(1, 3, 2)
plt.imshow(lu_.todense())
plt.title('L @ U  where: L, U = ILU0(A)')

b_ = b.copy()
b_.data = b_.data * 0 + 1

plt.subplot(1, 3, 3)
plt.imshow(b_.todense())
plt.title('L @ U - A')
# Out:
# Text(0.5, 1.0, 'L @ U - A')

# %%
b = l @ u - a

# b.data = b.data * 0 + 1
plt.imshow(b.todense())

# %%
import matplotlib.pyplot as plt

# a = A_pad_train[0, 0, ...] - A_train[0, ...]
a = A_train[0, ...]
a.data = a.data * 0 + 1
plt.imshow(a.todense())

# %%
# Out:
# Array(1.0078278, dtype=float32)

# %%
dt_ls
# Out:
# {32: 0.34731610970571636,
#  64: 0.34657173190265894,
#  128: 0.35035961179062725,
#  256: 0.36753516817465426}

# %%
import warnings
import sys
import os

warnings.filterwarnings('ignore')
os.environ["CUDA_VISIBLE_DEVICES"] = ''
os.environ['XLA_PYTHON_CLIENT_MEM_FRACTION'] = '1.'
sys.path.append('/mnt/local/data/vtrifonov/prec-learning-Notay-loss/')

import jax.numpy as jnp
import pandas as pd
from utils import parse_run, read_meta_data, df_threshold_residuals

# %%
loss = 'llt-res'
df = read_meta_data(loss)

# %%
df
# Out:
#        dataset  grid  N_samples_train  N_samples_test  rhs_train   rhs_test  \
# 7n0drp  krylov    64               10               5     random     random
# bgffjm  krylov    64               10               5  [5, 5, 2]  [5, 5, 2]
# seslm0  krylov    64               10               5     random     random
# dkkc3o  krylov    64               10               5  [5, 5, 2]  [5, 5, 2]
# wst7ql  krylov    64               10               5     random     random
# c69cjd  krylov    64               10               5  [5, 5, 2]  [5, 5, 2]
# xcqjer  krylov    64               10               5     random     random
# votwpc  krylov    64               10               5  [5, 5, 2]  [5, 5, 2]
# aox09c  krylov    64               10               5     random     random
# 16p8ga  krylov    64               10               5  [5, 5, 2]  [5, 5, 2]
# i9t9rm  krylov    64               10               5     random     random
# ...

# %%
q = "rhs_train == '[5, 5, 2]' and k_train == '[5, 5, 2]'"
check = df.query(q).index
df.query(q).loc[:, ['cond_prec_system', 'cond_initial_system', 'lhs_type', 'cg_I_1e_3', 'cg_I_1e_6', 'cg_I_1e_12', 'cg_LLT_1e_3', 'cg_LLT_1e_6', 'cg_LLT_1e_12']]
# df.query(q).loc[:, ['lhs_type']]
# Out:
#         cond_prec_system  cond_initial_system lhs_type  cg_I_1e_3  cg_I_1e_6  \
# votwpc        111.932335            242972.00       fd        161        254
# 16p8ga        107.913810            242972.00     ilu0        161        257
# qcz33c         82.651230            242992.38     ilu1        161        254
#
#         cg_I_1e_12  cg_LLT_1e_3  cg_LLT_1e_6  cg_LLT_1e_12
# votwpc         376          NaN          NaN           NaN
# 16p8ga         379          NaN          NaN           NaN
# qcz33c         376          NaN          NaN           NaN

# %%
parse_run(loss, check, (15, 10))
# Out:
#        dataset  grid  N_samples_train  N_samples_test  rhs_train   rhs_test  \
# votwpc  krylov    64               10               5  [5, 5, 2]  [5, 5, 2]
# 16p8ga  krylov    64               10               5  [5, 5, 2]  [5, 5, 2]
# qcz33c  krylov    64               10               5  [5, 5, 2]  [5, 5, 2]
#
#           k_train     k_test  rhs_offset_train  rhs_offset_test  \
# votwpc  [5, 5, 2]  [5, 5, 2]                 0                0
# 16p8ga  [5, 5, 2]  [5, 5, 2]                 0                0
# qcz33c  [5, 5, 2]  [5, 5, 2]                 0                0
#
#         k_offset_train  k_offset_test lhs_type  cg_repeats loss_type  \
# votwpc              10             10       fd         300   llt-res
# 16p8ga              10             10     ilu0         300   llt-res
# qcz33c              10             10     ilu1         300   llt-res
#
#                            loss_reduction  batch_size  epoch_num  lr_start  \
# ...

# %%
import jax.numpy as jnp
from jax import random, vmap, clear_caches, jit
import numpy as np

import optax
from equinox.nn import Conv1d
import matplotlib.pyplot as plt
from functools import partial
from time import perf_counter

from data.dataset import dataset_Krylov, dataset_FD
from linsolve.cg import ConjGrad
from linsolve.precond import llt_prec_trig_solve
from model import MessagePassing, FullyConnectedNet, PrecNet, ConstantConv1d, MessagePassingWithDot

from utils import params_count, asses_cond, iter_per_residual, batch_indices
from data.utils import direc_graph_from_linear_system_sparse
from train import train

# %% [markdown]
# # Setup experiment

# %%
dataset = 'krylov'                # 'krylov', 'simple'
grid = 64
N_samples_train = 30
N_samples_test = 5

# %%
rhs_train = rhs_test = 'random'           # 'random', 'laplace', [5, 5, 2]
k_train = k_test = 'poisson'           # 'random', 'poisson', [5, 5, 2]
rhs_offset_train = rhs_offset_test = 0
k_offset_train = k_offset_test = 10
lhs_type = 'ilu2'                        # 'fd', 'ilu0', 'ilu1', 'ilu2'

cg_repeats = 100
if dataset == 'simple': cg_repeats = 1

# %%
layer_ = ConstantConv1d         # 'ConstantConv1d' to make a "zero" NN initialization; 'Conv1d' to make a random initialization
loss_type = 'llt-res-norm'               # 'llt', 'llt-norm', 'notay', 'llt-res', 'llt-res-norm'
with_cond = True               # If True will calculate cond during training. Extremly bad scaling (materialization of matrix)
# with_final_cond = False         # If True will calculate cond with final L. Also bad scaling

loss_reduction = jnp.mean
# loss_reduction = jnp.mean if loss_type == 'notay' else jnp.sum

# %%
if (loss_type in {'notay', 'llt-res', 'llt-res-norm'} and dataset == 'simple') or (loss_type in {'llt', 'llt-norm'} and dataset == 'krylov'):
    raise ValueError('Not valid dataset for a chosen loss')

# %%
batch_size = 64
lr = 1e-3
epoch_num = 300

# %%
# # Uncomment and setup to make steps in learning rate

# steps_per_batch = N_samples_train * cg_repeats // batch_size
# start, stop, step = 45*steps_per_batch, 101*steps_per_batch, 45*steps_per_batch
# decay_size = 1e-1
# lr = optax.piecewise_constant_schedule(
#     lr,
# #     {k: v for k, v in zip([37], [1e-1])}
#     {k: v for k, v in zip(np.arange(start, stop, step), [decay_size, ] * len(jnp.arange(start, stop, step)))}
# )

# %% [markdown]
# # Make dataset

# %%
s1 = perf_counter()
if dataset == 'krylov':
    A_train, A_pad_train, b_train, u_exact_train, bi_edges_train, res_train, u_app_train = dataset_Krylov(grid, N_samples_train, seed=42, rhs_distr=rhs_train, rhs_offset=rhs_offset_train,
                                                                                             k_distr=k_train, k_offset=k_offset_train, cg_repeats=cg_repeats, lhs_type=lhs_type)
    A_test, A_pad_test, b_test, u_exact_test, bi_edges_test, res_test, u_app_test = dataset_Krylov(grid, N_samples_test, seed=43, rhs_distr=rhs_test, rhs_offset=rhs_offset_test,
                                                                                       k_distr=k_test, k_offset=k_offset_test, cg_repeats=cg_repeats, lhs_type=lhs_type)
elif dataset == 'simple':
    A_train, A_pad_train, b_train, u_exact_train, bi_edges_train = dataset_FD(grid, N_samples_train, seed=42, rhs_distr=rhs_train, rhs_offset=rhs_offset_train,
                                                                 k_distr=k_train, k_offset=k_offset_train, lhs_type=lhs_type)
    A_test, A_pad_test, b_test, u_exact_test, bi_edges_test = dataset_FD(grid, N_samples_test, seed=43, rhs_distr=rhs_test, rhs_offset=rhs_offset_test,
                                                             k_distr=k_test, k_offset=k_offset_test, lhs_type=lhs_type)
print(perf_counter() - s1)
# Out:
# CUDA backend failed to initialize: jaxlib/cuda/versions_helpers.cc:98: operation cuInit(0) failed: CUDA_ERROR_NO_DEVICE (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)
# 31.196216793963686

# %% [markdown]
# ## Tests

# %%
from functools import partial
from jax import jit
from jax.lax import scan, cond
import jax.numpy as jnp

@partial(jit, static_argnums=(2))
def jspsolve_triangular(A, b, lower):
    '''A must be a lower/upper triangular matrix.
       It should be "valid": not singular (have no zeros on diagonal, no empty rows, etc.)'''
    A = A.sort_indices()
    Aval, bval = A.data, b
    Arows, Acols = A.indices[:, 0], A.indices[:, 1]
    x = jnp.zeros_like(bval)    

    diag_edge_indx = jnp.diff(jnp.hstack([Arows[:, None], Acols[:, None]]))
    diag_edge_indx = jnp.where(diag_edge_indx == 0, 1, 0)
    diag_edge_indx = jnp.nonzero(diag_edge_indx, size=bval.shape[0], fill_value=jnp.nan)[0].astype(jnp.int32)

    if lower:
        xs_ = jnp.hstack([
            jnp.arange(x.shape[0])[:, None],
            diag_edge_indx[:, None]
        ])
    else:
        xs_ = jnp.hstack([
            jnp.arange(x.shape[0]-1, -1, -1)[:, None],
            diag_edge_indx[::-1][:, None]
        ])
    def f_(carry, k):
        i, diag_ind = k
        Aval_, Arows_, Acols_, bval_, x_ = carry
        
#         x_i = x_.at[jnp.where(Arows_ == i, Acols_, Acols_.shape[0])].get(mode='fill', fill_value=0)
#         x_i = lax.cond(cond, f_1, f_2, operand) -- should try
        
        x_i = vmap(cond, in_axes=(0, None, None, 0), out_axes=(0))(Arows_ == i, lambda j: x_[j], lambda j: 0., Acols_)
        A_i = jnp.where(Arows_ == i, Aval_, 0)
        
        c = (bval_[i] - jnp.sum(A_i * x_i)) / (Aval_[diag_ind] + 1e-9)
        x_ = x_.at[i].set(c)
        return (Aval_, Arows_, Acols_, bval_, x_), None
    
    carry_ = (Aval, Arows, Acols, bval, x)
    (_, _, _, _, x), _ = scan(f_, carry_, xs_)
    return x

# %%
# from data.utils import direc_graph_from_linear_system_sparse, graph_tril, graph_to_low_tri_mat_sparse
# from jax.experimental import sparse as jsparse 

# nodes, edges, receivers, senders, _ = direc_graph_from_linear_system_sparse(A_train, b_train)
# print(edges.shape, receivers.shape, senders.shape)
# nodes, edges, receivers, senders = nodes[0, ...][None, ...], edges[0, ...], receivers[0, ...], senders[0, ...]
# nodes, edges, receivers, senders = graph_tril(nodes, edges, receivers, senders)
# print(edges.shape, receivers.shape, senders.shape)

# # abc_tril = vmap(graph_to_low_tri_mat_sparse, in_axes=(0, 0, 0, 0), out_axes=(0))(nodes[None, ...], edges[None, ...], receivers[None, ...], senders[None, ...])
# abc_tril = graph_to_low_tri_mat_sparse(nodes, edges, receivers, senders)
# # abc_tril.data = abc_tril.data * 0 + 1
# plt.imshow(abc_tril.todense());

# %%
clear_caches()

l_ = True
arr = abc_tril if l_ else jsparse.sparsify(lambda A: A.T)(abc_tril)

dt = 0
for _ in range(100):
    s_ = perf_counter()
    x1 = jspsolve_triangular(arr, b_train[0, :], lower=l_)
    dt += perf_counter() - s_

# display(x1)
print(f'time: {dt:.0f} sec')
jnp.abs(nodes[0, :] - arr @ x1).max()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 4
#       1 clear_caches()
#       3 l_ = True
# ----> 4 arr = abc_tril if l_ else jsparse.sparsify(lambda A: A.T)(abc_tril)
#       6 dt = 0
#       7 for _ in range(100):
#
# NameError: name 'abc_tril' is not defined
