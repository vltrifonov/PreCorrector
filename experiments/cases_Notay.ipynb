# %%
import warnings
import sys
import os

warnings.filterwarnings('ignore')
os.environ["CUDA_VISIBLE_DEVICES"] = ''
sys.path.append('/mnt/local/data/vtrifonov/prec-learning-Notay-loss/')

# %%
from jax import numpy as jnp
import optax
import matplotlib.pyplot as plt

from train_utils import training_search

# %%
# Notay 32
batch_size = 8
lr = 5e-4
notay_g32_b8_e100_lr5e_4 = {
    'run_name': 'notay_g32_b8_e100_lr5e_4.npz',
    'grid': 32,
    'N_samples_train': 80,
    'N_samples_test': 20,
    'rhs_distr_train': [5, 5, 2],
    'rhs_distr_test': [5, 5, 2],
    'train_config': {
        'optimizer': optax.adam,
        'lr': lr,
        'optim_params': {},#{'weight_decay': 1e-8}, 
        'epoch_num': 100,
        'batch_size': batch_size
    },
    'loss_name': 'notay',
    'with_cond': True,
    'normalize': False,
}
batch_size = 16
lr = 5e-4
notay_g32_b16_e100_lr5e_4 = {
    'run_name': 'notay_g32_b16_e100_lr5e_4.npz',
    'grid': 32,
    'N_samples_train': 80,
    'N_samples_test': 20,
    'rhs_distr_train': [5, 5, 2],
    'rhs_distr_test': [5, 5, 2],
    'train_config': {
        'optimizer': optax.adam,
        'lr': lr,
        'optim_params': {},#{'weight_decay': 1e-8}, 
        'epoch_num': 100,
        'batch_size': batch_size
    },
    'loss_name': 'notay',
    'with_cond': True,
    'normalize': False,
}
batch_size = 32
lr = 5e-4
notay_g32_b32_e100_lr5e_4 = {
    'run_name': 'notay_g32_b32_e100_lr5e_4.npz',
    'grid': 32,
    'N_samples_train': 80,
    'N_samples_test': 20,
    'rhs_distr_train': [5, 5, 2],
    'rhs_distr_test': [5, 5, 2],
    'train_config': {
        'optimizer': optax.adam,
        'lr': lr,
        'optim_params': {},#{'weight_decay': 1e-8}, 
        'epoch_num': 100,
        'batch_size': batch_size
    },
    'loss_name': 'notay',
    'with_cond': True,
    'normalize': False,
}
batch_size = 64
lr = 5e-4
notay_g32_b64_e100_lr5e_4 = {
    'run_name': 'notay_g32_b64_e100_lr5e_4.npz',
    'grid': 32,
    'N_samples_train': 80,
    'N_samples_test': 20,
    'rhs_distr_train': [5, 5, 2],
    'rhs_distr_test': [5, 5, 2],
    'train_config': {
        'optimizer': optax.adam,
        'lr': lr,
        'optim_params': {},#{'weight_decay': 1e-8}, 
        'epoch_num': 100,
        'batch_size': batch_size
    },
    'loss_name': 'notay',
    'with_cond': True,
    'normalize': False,
}
batch_size = 80
lr = 5e-4
notay_g32_b80_e100_lr5e_4 = {
    'run_name': 'notay_g32_b80_e100_lr5e_4.npz',
    'grid': 32,
    'N_samples_train': 80,
    'N_samples_test': 20,
    'rhs_distr_train': [5, 5, 2],
    'rhs_distr_test': [5, 5, 2],
    'train_config': {
        'optimizer': optax.adam,
        'lr': lr,
        'optim_params': {},#{'weight_decay': 1e-8}, 
        'epoch_num': 100,
        'batch_size': batch_size
    },
    'loss_name': 'notay',
    'with_cond': True,
    'normalize': False,
}
batch_size = 32
lr = 1e-4
notay_g32_b32_e200_lr1e_4 = {
    'run_name': 'notay_g32_b32_e200_lr1e_4.npz',
    'grid': 32,
    'N_samples_train': 80,
    'N_samples_test': 20,
    'rhs_distr_train': [5, 5, 2],
    'rhs_distr_test': [5, 5, 2],
    'train_config': {
        'optimizer': optax.adam,
        'lr': lr,
        'optim_params': {},#{'weight_decay': 1e-8}, 
        'epoch_num': 200,
        'batch_size': batch_size
    },
    'loss_name': 'notay',
    'with_cond': True,
    'normalize': False,
}
batch_size = 16
lr = 1e-4
notay_g32_b16_e200_lr1e_4 = {
    'run_name': 'notay_g32_b16_e200_lr1e_4.npz',
    'grid': 32,
    'N_samples_train': 80,
    'N_samples_test': 20,
    'rhs_distr_train': [5, 5, 2],
    'rhs_distr_test': [5, 5, 2],
    'train_config': {
        'optimizer': optax.adam,
        'lr': lr,
        'optim_params': {},#{'weight_decay': 1e-8}, 
        'epoch_num': 200,
        'batch_size': batch_size
    },
    'loss_name': 'notay',
    'with_cond': True,
    'normalize': False,
}

# %%
# Notay 64
batch_size = 8
lr = 5e-4
notay_g64_b8_e100_lr5e_4 = {
    'run_name': 'notay_g64_b8_e100_lr5e_4.npz',
    'grid': 64,
    'N_samples_train': 60,
    'N_samples_test': 10,
    'rhs_distr_train': [5, 5, 2],
    'rhs_distr_test': [5, 5, 2],
    'train_config': {
        'optimizer': optax.adam,
        'lr': lr,
        'optim_params': {},#{'weight_decay': 1e-8}, 
        'epoch_num': 100,
        'batch_size': batch_size
    },
    'loss_name': 'notay',
    'with_cond': True,
    'normalize': False,
}
batch_size = 16
lr = 5e-4
notay_g64_b16_e100_lr5e_4 = {
    'run_name': 'notay_g64_b16_e100_lr5e_4.npz',
    'grid': 64,
    'N_samples_train': 60,
    'N_samples_test': 10,
    'rhs_distr_train': [5, 5, 2],
    'rhs_distr_test': [5, 5, 2],
    'train_config': {
        'optimizer': optax.adam,
        'lr': lr,
        'optim_params': {},#{'weight_decay': 1e-8}, 
        'epoch_num': 100,
        'batch_size': batch_size
    },
    'loss_name': 'notay',
    'with_cond': True,
    'normalize': False,
}
batch_size = 32
lr = 5e-4
notay_g64_b32_e100_lr5e_4 = {
    'run_name': 'notay_g64_b32_e100_lr5e_4.npz',
    'grid': 64,
    'N_samples_train': 60,
    'N_samples_test': 10,
    'rhs_distr_train': [5, 5, 2],
    'rhs_distr_test': [5, 5, 2],
    'train_config': {
        'optimizer': optax.adam,
        'lr': lr,
        'optim_params': {},#{'weight_decay': 1e-8}, 
        'epoch_num': 100,
        'batch_size': batch_size
    },
    'loss_name': 'notay',
    'with_cond': True,
    'normalize': False,
}
batch_size = 64
lr = 5e-4
notay_g64_b64_e100_lr5e_4 = {
    'run_name': 'notay_g64_b64_e100_lr5e_4.npz',
    'grid': 64,
    'N_samples_train': 60,
    'N_samples_test': 10,
    'rhs_distr_train': [5, 5, 2],
    'rhs_distr_test': [5, 5, 2],
    'train_config': {
        'optimizer': optax.adam,
        'lr': lr,
        'optim_params': {},#{'weight_decay': 1e-8}, 
        'epoch_num': 100,
        'batch_size': batch_size
    },
    'loss_name': 'notay',
    'with_cond': True,
    'normalize': False,
}
batch_size = 80
lr = 5e-4
notay_g64_b80_e100_lr5e_4 = {
    'run_name': 'notay_g64_b80_e100_lr5e_4.npz',
    'grid': 64,
    'N_samples_train': 60,
    'N_samples_test': 10,
    'rhs_distr_train': [5, 5, 2],
    'rhs_distr_test': [5, 5, 2],
    'train_config': {
        'optimizer': optax.adam,
        'lr': lr,
        'optim_params': {},#{'weight_decay': 1e-8}, 
        'epoch_num': 100,
        'batch_size': batch_size
    },
    'loss_name': 'notay',
    'with_cond': True,
    'normalize': False,
}
batch_size = 32
lr = 1e-4
notay_g64_b32_e200_lr1e_4 = {
    'run_name': 'notay_g64_b32_e200_lr1e_4.npz',
    'grid': 64,
    'N_samples_train': 60,
    'N_samples_test': 10,
    'rhs_distr_train': [5, 5, 2],
    'rhs_distr_test': [5, 5, 2],
    'train_config': {
        'optimizer': optax.adam,
        'lr': lr,
        'optim_params': {},#{'weight_decay': 1e-8}, 
        'epoch_num': 200,
        'batch_size': batch_size
    },
    'loss_name': 'notay',
    'with_cond': True,
    'normalize': False,
}
batch_size = 16
lr = 1e-4
notay_g64_b16_e200_lr1e_4 = {
    'run_name': 'notay_g64_b16_e200_lr1e_4.npz',
    'grid': 64,
    'N_samples_train': 60,
    'N_samples_test': 10,
    'rhs_distr_train': [5, 5, 2],
    'rhs_distr_test': [5, 5, 2],
    'train_config': {
        'optimizer': optax.adam,
        'lr': lr,
        'optim_params': {},#{'weight_decay': 1e-8}, 
        'epoch_num': 200,
        'batch_size': batch_size
    },
    'loss_name': 'notay',
    'with_cond': True,
    'normalize': False,
}

# %%
dir_ = '/mnt/local/data/vtrifonov/prec-learning-Notay-loss/results_cases'
date = '01-04-20224'
config_ls = [notay_g32_b8_e100_lr5e_4, notay_g32_b16_e100_lr5e_4, notay_g32_b32_e100_lr5e_4, notay_g32_b64_e100_lr5e_4,
            notay_g32_b80_e100_lr5e_4, notay_g32_b32_e200_lr1e_4, notay_g32_b16_e200_lr1e_4, notay_g64_b8_e100_lr5e_4, notay_g64_b16_e100_lr5e_4, notay_g64_b32_e100_lr5e_4, 
            notay_g64_b64_e100_lr5e_4, notay_g64_b80_e100_lr5e_4, notay_g64_b32_e200_lr1e_4, notay_g64_b16_e200_lr1e_4]

# %%
# training_search(config_ls, date)
# Out:
# Started: notay_g32_b8_e100_lr5e_4.npz
# 2024-04-01 17:29:19.367595: W external/xla/xla/service/gpu/nvptx_compiler.cc:744] The NVIDIA driver's CUDA version is 12.2 which is older than the ptxas CUDA version (12.3.107). Because the driver is older than the ptxas version, XLA is disabling parallel compilation, which may slow down compilation. You should update your NVIDIA driver or use the NVIDIA-provided CUDA forward compatibility packages.
# Started: notay_g32_b16_e100_lr5e_4.npz
# Started: notay_g32_b32_e100_lr5e_4.npz

# %%
config_g32 = [notay_g32_b8_e100_lr5e_4, notay_g32_b16_e100_lr5e_4, notay_g32_b32_e100_lr5e_4, notay_g32_b64_e100_lr5e_4,
            notay_g32_b80_e100_lr5e_4, notay_g32_b32_e200_lr1e_4, notay_g32_b16_e200_lr1e_4]

config_g64 = [notay_g64_b8_e100_lr5e_4, notay_g64_b16_e100_lr5e_4, notay_g64_b32_e100_lr5e_4, 
              notay_g64_b32_e200_lr1e_4, notay_g64_b16_e200_lr1e_4]

# %%
plt.rcParams['font.size'] = 10
_, axes = plt.subplots(len(config_g64), 3, figsize=(20, 20))

for i, c in enumerate(config_g64):
    check = jnp.load(os.path.join(dir_, date, c['run_name']))
    n = c['run_name'][4:c['run_name'].find('.')]
    losses = check['losses']
    R_I = check['res_I']
    R_LLT = check['res_LLT']

    axes[i, 0].plot(range(len(losses[0])), losses[1], label='Test')
    axes[i, 0].plot(range(len(losses[0])), losses[0], label='Train')
    axes[i, 0].legend(fontsize=7)
    axes[i, 0].set_yscale('log')
    axes[i, 0].set_xlabel('Epoch')
    axes[i, 0].set_ylabel(f'{n}\nLoss')
    axes[i, 0].grid()
    
    try:
        axes[i, 1].plot(range(len(losses[0])), losses[2], label='Test')
        axes[i, 1].legend(fontsize=7)
        axes[i, 1].set_yscale('log')
        axes[i, 1].set_xlabel('Epoch')
        axes[i, 1].set_ylabel('Cond of $LL^T$')
        axes[i, 1].grid();
    except: pass
    
    axes[i, 2].plot(range(R_I.shape[-1]), R_I, label="Not prec")
    axes[i, 2].plot(range(R_LLT.shape[-1]), R_LLT, label="Notay")

    axes[i, 2].set_xlabel('Iteration')
    axes[i, 2].set_ylabel('Norm residuals')
    axes[i, 2].legend(fontsize=7);
    axes[i, 2].set_yscale('log')
    axes[i, 2].grid();
plt.tight_layout;

# %%
config_notay_best = [notay_g32_b64_e100_lr5e_4, notay_g64_b16_e100_lr5e_4]

# %%
plt.rcParams['font.size'] = 10
_, axes = plt.subplots(2, 3, figsize=(14, 7))

for i, c in enumerate(config_notay_best):
    check = jnp.load(os.path.join(dir_, date, c['run_name']))
    n = c['run_name'][6:9]
    losses = check['losses']
    R_I = check['res_I']
    R_LLT = check['res_LLT']

    axes[i, 0].plot(range(len(losses[0])), losses[1], label='Test')
    axes[i, 0].plot(range(len(losses[0])), losses[0], label='Train')
    axes[i, 0].legend()
    axes[i, 0].set_yscale('log')
    axes[i, 0].set_xlabel('Epoch')
    axes[i, 0].set_ylabel(f'{n}\nLoss')
    axes[i, 0].grid()
    
    try:
        axes[i, 1].plot(range(len(losses[0])), losses[2], label='Test')
        axes[i, 1].legend()
        axes[i, 1].set_yscale('log')
        axes[i, 1].set_xlabel('Epoch')
        axes[i, 1].set_ylabel('Cond of $LL^T$')
        axes[i, 1].grid();
    except: pass
    
    axes[i, 2].plot(range(R_I.shape[-1]), R_I, label="Not prec")
    axes[i, 2].plot(range(R_LLT.shape[-1]), R_LLT, label="$\|LL^Tx - b\|_2^2$")

    axes[i, 2].set_xlabel('Iteration')
    axes[i, 2].set_ylabel('Norm residuals')
    axes[i, 2].legend();
    axes[i, 2].set_yscale('log')
    axes[i, 2].grid();
plt.tight_layout()
