# %%
import warnings
import sys
import os
import jax

# os.environ['JAX_PLATFORMS'] = 'cpu'
os.environ["CUDA_VISIBLE_DEVICES"] = '2'
os.environ['XLA_PYTHON_CLIENT_MEM_FRACTION'] = '.95'
jax.config.update("jax_enable_x64", True)
warnings.filterwarnings('ignore')
sys.path.append('/mnt/local/data/vtrifonov/prec-learning-Notay-loss/')

# %%
import jax.experimental.sparse as jsparse
import jax.numpy as jnp
from jax import device_put, random
from jax.lax import scan
import numpy as np

import matplotlib.pyplot as plt
from functools import partial
from time import perf_counter
import ilupp

from data.dataset import dataset_qtt
from linsolve.scipy_linsolve import batched_cg_scipy, make_Chol_prec
from utils import iter_per_residual, jBCOO_to_scipyCSR

plt.rcParams['figure.figsize'] = (11, 7)
plt.rcParams['font.size'] = 20
plt.rcParams["lines.linewidth"] = 3

# %%
A = jnp.zeros(10)
# Out:
# ---------------------------------------------------------------------------
# XlaRuntimeError                           Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# File /usr/local/lib/python3.10/dist-packages/jax/_src/xla_bridge.py:965, in _init_backend(platform)
#     964 logger.debug("Initializing backend '%s'", platform)
# --> 965 backend = registration.factory()
#     966 # TODO(skye): consider raising more descriptive errors directly from backend
#     967 # factories instead of returning None.
#
# File /usr/local/lib/python3.10/dist-packages/jax/_src/xla_bridge.py:663, in register_plugin.<locals>.factory()
#     662 if distributed.global_state.client is None:
# --> 663   return xla_client.make_c_api_client(plugin_name, updated_options, None)
#     665 distribute_options = {
#     666     'node_id': distributed.global_state.process_id,
#     667     'num_nodes': distributed.global_state.num_processes,
#     668 }
#
# File /usr/local/lib/python3.10/dist-packages/jaxlib/xla_client.py:199, in make_c_api_client(plugin_name, options, distributed_client)
#     198   options = {}
# --> 199 return _xla.get_c_api_client(plugin_name, options, distributed_client)
#
# XlaRuntimeError: INTERNAL: no supported devices found for platform CUDA
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 A = jnp.zeros(10)
#
# File /usr/local/lib/python3.10/dist-packages/jax/_src/numpy/lax_numpy.py:2782, in zeros(shape, dtype, device)
#    2780 dtypes.check_user_dtype_supported(dtype, "zeros")
#    2781 shape = canonicalize_shape(shape)
# -> 2782 return lax.full(shape, 0, _jnp_dtype(dtype), sharding=_normalize_to_sharding(device))
#
# File /usr/local/lib/python3.10/dist-packages/jax/_src/lax/lax.py:1246, in full(shape, fill_value, dtype, sharding)
#    1244 weak_type = dtype is None and dtypes.is_weakly_typed(fill_value)
#    1245 dtype = dtypes.canonicalize_dtype(dtype or _dtype(fill_value))
# -> 1246 fill_value = _convert_element_type(fill_value, dtype, weak_type)
#    1247 # In tracing mode we can't set sharing explictly and PmapShardng is not
#    1248 # supported.
#    1249 # NB: Consider using with_sharding_constraint in jitted computation
#    1250 # if needed?
#    1251 if (sharding is not None and not isinstance(sharding, PmapSharding) and
#    1252     isinstance(fill_value, array.ArrayImpl)):
#
# File /usr/local/lib/python3.10/dist-packages/jax/_src/lax/lax.py:559, in _convert_element_type(operand, new_dtype, weak_type)
#     557   return type_cast(Array, operand)
#     558 else:
# --> 559   return convert_element_type_p.bind(operand, new_dtype=new_dtype,
#     560                                      weak_type=bool(weak_type))
#
# File /usr/local/lib/python3.10/dist-packages/jax/_src/core.py:387, in Primitive.bind(self, *args, **params)
#     384 def bind(self, *args, **params):
#     385   assert (not config.enable_checks.value or
#     386           all(isinstance(arg, Tracer) or valid_jaxtype(arg) for arg in args)), args
# --> 387   return self.bind_with_trace(find_top_trace(args), args, params)
#
# File /usr/local/lib/python3.10/dist-packages/jax/_src/core.py:391, in Primitive.bind_with_trace(self, trace, args, params)
#     389 def bind_with_trace(self, trace, args, params):
#     390   with pop_level(trace.level):
# --> 391     out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     392   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File /usr/local/lib/python3.10/dist-packages/jax/_src/core.py:879, in EvalTrace.process_primitive(self, primitive, tracers, params)
#     877   return call_impl_with_key_reuse_checks(primitive, primitive.impl, *tracers, **params)
#     878 else:
# --> 879   return primitive.impl(*tracers, **params)
#
# File /usr/local/lib/python3.10/dist-packages/jax/_src/dispatch.py:86, in apply_primitive(prim, *args, **params)
#      84 prev = lib.jax_jit.swap_thread_local_state_disable_jit(False)
#      85 try:
# ---> 86   outs = fun(*args)
#      87 finally:
#      88   lib.jax_jit.swap_thread_local_state_disable_jit(prev)
#
#     [... skipping hidden 17 frame]
#
# File /usr/local/lib/python3.10/dist-packages/jax/_src/xla_bridge.py:890, in backends()
#     888       else:
#     889         err_msg += " (you may need to uninstall the failing plugin package, or set JAX_PLATFORMS=cpu to skip this backend.)"
# --> 890       raise RuntimeError(err_msg)
#     892 assert _default_backend is not None
#     893 if not config.jax_platforms.value:
#
# RuntimeError: Unable to initialize backend 'cuda': INTERNAL: no supported devices found for platform CUDA (you may need to uninstall the failing plugin package, or set JAX_PLATFORMS=cpu to skip this backend.)

# %% [markdown]
# # Benchmark dataset

# %%
def scipy_benchmark_linsys(A, b, cg_iter, pcg_iter, atol):
    L0, Lt1, Lt5 = [], [], []
    L0_time, Lt1_time, Lt5_time = [], [], []
    Annz, L0nnz, Lt1nnz, Lt5nnz = [], [], [], []
    
    for i in range(A.shape[0]):
        A_i = jBCOO_to_scipyCSR(A[i, ...])
        Annz.append((A_i.nnz*100) / (A_i.shape[-1] ** 2))
        
        # IC(0)
        s = perf_counter()
        L0_i = ilupp.ichol0(A_i)
        L0_time.append(perf_counter() - s)
        L0.append(L0_i)
        L0nnz.append((L0_i.nnz*100) / (L0_i.shape[-1] ** 2))

        # ICt(1)
        s = perf_counter()
        Lt1_i = ilupp.icholt(A_i, add_fill_in=1, threshold=1e-4)
        Lt1_time.append(perf_counter() - s)
        Lt1.append(Lt1_i)
        Lt1nnz.append((Lt1_i.nnz*100) / (Lt1_i.shape[-1] ** 2))
        
        # ICt(5)
        s = perf_counter()
        Lt5_i = ilupp.icholt(A_i, add_fill_in=5, threshold=1e-4)
        Lt5_time.append(perf_counter() - s)
        Lt5.append(Lt5_i)
        Lt5nnz.append((Lt5_i.nnz*100) / (Lt5_i.shape[-1] ** 2))
    
    ## Save precs props
    # Average time
    comb_L0_time = [np.mean(L0_time), np.std(L0_time)]
    comb_Lt1_time = [np.mean(Lt1_time), np.std(Lt1_time)]
    comb_Lt5_time  = [np.mean(Lt5_time), np.std(Lt5_time)]
    
    # Average nnz
    Annz = [np.mean(Annz), np.std(Annz)]
    L0nnz = [np.mean(L0nnz), np.std(L0nnz)]
    Lt1nnz = [np.mean(Lt1nnz), np.std(Lt1nnz)]
    Lt5nnz = [np.mean(Lt5nnz), np.std(Lt5nnz)]
    
    ## Assemble precs
    P_L0 = make_Chol_prec(L0)
    P_Lt1 = make_Chol_prec(Lt1)
    P_Lt5 = make_Chol_prec(Lt5)
    print('  Precs are combined')
        
    ## Run PCG
    # I
    if isinstance(cg_iter, int):
        _, I_iters_mean, I_iters_std, I_time_mean, I_time_std = batched_cg_scipy(A, b, P=None, atol=atol, maxiter=cg_iter)
    #     res_I_mean = list(iter_per_residual(res_ls.mean(0)).values())
    #     res_I_std = res_ls.std(0)[res_I_mean]
    #     time_I_mean = time_ls.mean(0)[res_I_mean]
    #     time_I_std = time_ls.std(0)[res_I_mean]
        print('  I is done')
    else:
        I_iters_mean, I_iters_std, I_time_mean, I_time_std = [-1]*4, [-1]*4, [-1]*4, [-1]*4
        print('  I is skipped')

    # L0
    _, L0_iters_mean, L0_iters_std, L0_time_mean, L0_time_std = batched_cg_scipy(A, b, P=P_L0, atol=atol, maxiter=pcg_iter)
#     res_L0_mean = list(iter_per_residual(res_ls.mean(0)).values())
#     res_L0_std = res_ls.std(0)[res_L0_mean]
#     time_L0_mean = time_ls.mean(0)[res_L0_mean]
#     time_L0_std = time_ls.std(0)[res_L0_mean]
    print('  L0 is done')

    # Lt1
    _, Lt1_iters_mean, Lt1_iters_std, Lt1_time_mean, Lt1_time_std = batched_cg_scipy(A, b, P=P_Lt1, atol=atol, maxiter=pcg_iter)
#     res_Lt1_mean = list(iter_per_residual(res_ls.mean(0)).values())
#     res_Lt1_std = res_ls.std(0)[res_Lt1_mean]
#     time_Lt1_mean = time_ls.mean(0)[res_Lt1_mean]
#     time_Lt1_std = time_ls.std(0)[res_Lt1_mean]
    print('  Lt1 is done')

    # Lt5
    _, Lt5_iters_mean, Lt5_iters_std, Lt5_time_mean, Lt5_time_std = batched_cg_scipy(A, b, P=P_Lt5, atol=atol, maxiter=pcg_iter)
#     res_Lt5_mean = list(iter_per_residual(res_ls.mean(0)).values())
#     res_Lt5_std = res_ls.std(0)[res_Lt5_mean]
#     time_Lt5_mean = time_ls.mean(0)[res_Lt5_mean]
#     time_Lt5_std = time_ls.std(0)[res_Lt5_mean]
    print('  Lt5 is done')
    out = (
        (Annz, I_iters_mean, I_iters_std, I_time_mean, I_time_std, [-1, -1]),
        (L0nnz, L0_iters_mean, L0_iters_std, L0_time_mean, L0_time_std, comb_L0_time),
        (Lt1nnz, Lt1_iters_mean, Lt1_iters_std, Lt1_time_mean, Lt1_time_std, comb_Lt1_time),
        (Lt5nnz, Lt5_iters_mean, Lt5_iters_std, Lt5_time_mean, Lt5_time_std, comb_Lt5_time),        
    )
    return out

# %%
# def combine_mean_std(arr_mean, arr_std, tol_ls=[1e-3, 1e-6, 1e-9, 1e-12]):
#     for i, t in enumerate(tol_ls):
#         mean_t, std_t = arr_mean[i], arr_std[i]
#         print(f'{t}: {mean_t:.1f}±{std_t:.3f}', end='; ')
#     print()
#     return

def print_results(prec_name, results, tol_ls=[1e-3, 1e-6, 1e-9, 1e-12]):
    nnz, res_mean, res_std = results[0], results[1], results[2]
    cg_time_mean, cg_time_std, prec_time = results[3], results[4], results[5]
    
    print(f'{prec_name}, nnz = {nnz[0]:.3f}±{nnz[1]:.3f}, prec time = {prec_time[0]:6f}±{prec_time[1]:6f}')
    print('Residuals:   ', end='')
    for i, t in enumerate(tol_ls):
        mean_t, std_t = res_mean[i], res_std[i]
        print(f'{t}: {mean_t:.0f}±{std_t:.2f}', end='; ')
    print()
    
    print('Time:        ', end='')
    for i, t in enumerate(tol_ls):
        mean_t, std_t = cg_time_mean[i], cg_time_std[i]
        print(f'{t}: {mean_t:.4f}±{std_t:.5f}', end='; ')
    print(end='\n\n')
    return

# %%
def scipy_benchmark_all(params_grid, N, cg_iter, pcg_iter, atol):
    for p in params_grid:
        print(p)
        A, _, b, _, _ = dataset_qtt(pde=p[0], grid=p[1], variance=p[2], lhs_type='fd', return_train=False, N_samples=N, precision='f64')
        out = scipy_benchmark_linsys(A, b, cg_iter=cg_iter, pcg_iter=pcg_iter, atol=atol)
        for i, name in enumerate(['I', 'L0', 'Lt1', 'Lt5']):
            print_results(name, out[i])
        print('------------------------------------------------------------------------------------------------\n')
    return

# %%
params_grid = [
#     ['poisson',    32,  .1],
#     ['poisson',    64,  .1],
#     ['poisson',    128, .1],
# # 
#     ['div_k_grad', 32,  .1],
#     ['div_k_grad', 64,  .1],
#     ['div_k_grad', 128, .1],
# #     
#     ['div_k_grad', 32,  .5],
#     ['div_k_grad', 64,  .5],
#     ['div_k_grad', 128, .5],
# #
#     ['div_k_grad', 32,  .7],
#     ['div_k_grad', 64,  .7],
    ['div_k_grad', 128, .7]
]

# %%
scipy_benchmark_all(params_grid, N=200, cg_iter=None, pcg_iter=350, atol=0)
# Out:
# ['div_k_grad', 128, 0.7]
# 2024-09-22 10:46:31.603035: W external/xla/xla/service/gpu/nvptx_compiler.cc:760] The NVIDIA driver's CUDA version is 12.4 which is older than the ptxas CUDA version (12.5.40). Because the driver is older than the ptxas version, XLA is disabling parallel compilation, which may slow down compilation. You should update your NVIDIA driver or use the NVIDIA-provided CUDA forward compatibility packages.
#   Precs are combined
#   I is skipped
#   L0 is done
#   Lt1 is done
#   Lt5 is done
# I, nnz = 0.030±0.000, prec time = -1.000000±-1.000000
# Residuals:   0.001: -1±-1.00; 1e-06: -1±-1.00; 1e-09: -1±-1.00; 1e-12: -1±-1.00;
# Time:        0.001: -1.0000±-1.00000; 1e-06: -1.0000±-1.00000; 1e-09: -1.0000±-1.00000; 1e-12: -1.0000±-1.00000;
#
# L0, nnz = 0.018±0.000, prec time = 0.000511±0.000056
# Residuals:   0.001: 156±5.64; 1e-06: 196±5.54; 1e-09: 228±5.74; 1e-12: 255±5.71;
# Time:        0.001: 1.0699±0.18899; 1e-06: 1.3378±0.22872; 1e-09: 1.5534±0.26056; 1e-12: 1.7380±0.28744;
#
# Lt1, nnz = 0.024±0.000, prec time = 0.003794±0.000377
# Residuals:   0.001: 95±3.50; 1e-06: 119±3.40; 1e-09: 139±3.48; 1e-12: 156±3.50;
# Time:        0.001: 0.7165±0.09804; 1e-06: 0.8981±0.12170; 1e-09: 1.0442±0.14101; 1e-12: 1.1701±0.15705;
#
# Lt5, nnz = 0.048±0.000, prec time = 0.008916±0.000888
# Residuals:   0.001: 48±1.65; 1e-06: 60±1.60; 1e-09: 70±1.78; 1e-12: 79±1.70;
# Time:        0.001: 0.5609±0.07046; 1e-06: 0.7054±0.08779; 1e-09: 0.8241±0.10418; 1e-12: 0.9259±0.11719;
#
# ------------------------------------------------------------------------------------------------

# %%
scipy_benchmark_all(params_grid, N=200, cg_iter=None, pcg_iter=270, atol=0)
# Out:
# ['div_k_grad', 128, 0.1]
# 2024-09-22 09:34:27.168750: W external/xla/xla/service/gpu/nvptx_compiler.cc:760] The NVIDIA driver's CUDA version is 12.4 which is older than the ptxas CUDA version (12.5.40). Because the driver is older than the ptxas version, XLA is disabling parallel compilation, which may slow down compilation. You should update your NVIDIA driver or use the NVIDIA-provided CUDA forward compatibility packages.
#   Precs are combined
#   I is skipped
#   L0 is done
#   Lt1 is done
#   Lt5 is done
# I, nnz = 0.030±0.000, prec time = -1.000000±-1.000000
# Residuals:   0.001: -1±-1.00; 1e-06: -1±-1.00; 1e-09: -1±-1.00; 1e-12: -1±-1.00;
# Time:        0.001: -1.0000±-1.00000; 1e-06: -1.0000±-1.00000; 1e-09: -1.0000±-1.00000; 1e-12: -1.0000±-1.00000;
#
# L0, nnz = 0.018±0.000, prec time = 0.000462±0.000083
# Residuals:   0.001: 131±3.15; 1e-06: 168±1.93; 1e-09: 198±1.91; 1e-12: 224±2.04;
# Time:        0.001: 0.9912±0.15276; 1e-06: 1.2669±0.19113; 1e-09: 1.4882±0.22132; 1e-12: 1.6878±0.24817;
#
# Lt1, nnz = 0.024±0.000, prec time = 0.003374±0.000048
# Residuals:   0.001: 80±1.87; 1e-06: 102±1.32; 1e-09: 120±1.09; 1e-12: 137±1.20;
# Time:        0.001: 0.5520±0.07420; 1e-06: 0.7057±0.09218; 1e-09: 0.8300±0.10881; 1e-12: 0.9421±0.12329;
#
# Lt5, nnz = 0.048±0.000, prec time = 0.007940±0.000072
# Residuals:   0.001: 42±1.07; 1e-06: 54±0.80; 1e-09: 64±0.68; 1e-12: 73±0.67;
# Time:        0.001: 0.4799±0.07443; 1e-06: 0.6171±0.09486; 1e-09: 0.7280±0.11164; 1e-12: 0.8288±0.12769;
#
# ------------------------------------------------------------------------------------------------
#
# ['div_k_grad', 32, 0.5]
#   Precs are combined
#   I is skipped
#   L0 is done
#   Lt1 is done
#   Lt5 is done
# I, nnz = 0.476±0.000, prec time = -1.000000±-1.000000
# Residuals:   0.001: -1±-1.00; 1e-06: -1±-1.00; 1e-09: -1±-1.00; 1e-12: -1±-1.00;
# Time:        0.001: -1.0000±-1.00000; 1e-06: -1.0000±-1.00000; 1e-09: -1.0000±-1.00000; 1e-12: -1.0000±-1.00000;
#
# L0, nnz = 0.287±0.000, prec time = 0.000072±0.000005
# Residuals:   0.001: 36±1.24; 1e-06: 47±1.20; 1e-09: 56±1.21; 1e-12: 63±1.17;
# Time:        0.001: 0.0523±0.06076; 1e-06: 0.0655±0.06073; 1e-09: 0.0766±0.06075; 1e-12: 0.0861±0.06078;
#
# Lt1, nnz = 0.378±0.000, prec time = 0.000263±0.000007
# Residuals:   0.001: 21±0.73; 1e-06: 28±0.72; 1e-09: 33±0.70; 1e-12: 38±0.76;
# Time:        0.001: 0.0274±0.00102; 1e-06: 0.0350±0.00107; 1e-09: 0.0415±0.00113; 1e-12: 0.0473±0.00126;
#
# Lt5, nnz = 0.755±0.001, prec time = 0.000590±0.000012
# Residuals:   0.001: 10±0.37; 1e-06: 14±0.36; 1e-09: 17±0.31; 1e-12: 20±0.31;
# Time:        0.001: 0.0165±0.00068; 1e-06: 0.0217±0.00067; 1e-09: 0.0260±0.00071; 1e-12: 0.0301±0.00078;
#
# ------------------------------------------------------------------------------------------------
#
# ['div_k_grad', 64, 0.5]
#   Precs are combined
#   I is skipped
#   L0 is done
#   Lt1 is done
#   Lt5 is done
# I, nnz = 0.121±0.000, prec time = -1.000000±-1.000000
# Residuals:   0.001: -1±-1.00; 1e-06: -1±-1.00; 1e-09: -1±-1.00; 1e-12: -1±-1.00;
# Time:        0.001: -1.0000±-1.00000; 1e-06: -1.0000±-1.00000; 1e-09: -1.0000±-1.00000; 1e-12: -1.0000±-1.00000;
#
# L0, nnz = 0.072±0.000, prec time = 0.000158±0.000013
# Residuals:   0.001: 73±2.06; 1e-06: 93±2.14; 1e-09: 109±2.20; 1e-12: 124±2.15;
# Time:        0.001: 0.1648±0.06875; 1e-06: 0.2071±0.06940; 1e-09: 0.2419±0.06954; 1e-12: 0.2724±0.06966;
#
# Lt1, nnz = 0.096±0.000, prec time = 0.000962±0.000122
# Residuals:   0.001: 44±1.32; 1e-06: 56±1.34; 1e-09: 66±1.44; 1e-12: 75±1.37;
# Time:        0.001: 0.1000±0.00293; 1e-06: 0.1265±0.00308; 1e-09: 0.1488±0.00337; 1e-12: 0.1683±0.00319;
#
# Lt5, nnz = 0.192±0.000, prec time = 0.002196±0.000125
# Residuals:   0.001: 21±0.78; 1e-06: 28±0.68; 1e-09: 33±0.67; 1e-12: 38±0.64;
# Time:        0.001: 0.0657±0.00233; 1e-06: 0.0838±0.00203; 1e-09: 0.0995±0.00207; 1e-12: 0.1132±0.00198;
#
# ------------------------------------------------------------------------------------------------
#
# ['div_k_grad', 128, 0.5]
#   Precs are combined
#   I is skipped
#   L0 is done
#   Lt1 is done
#   Lt5 is done
# I, nnz = 0.030±0.000, prec time = -1.000000±-1.000000
# Residuals:   0.001: -1±-1.00; 1e-06: -1±-1.00; 1e-09: -1±-1.00; 1e-12: -1±-1.00;
# Time:        0.001: -1.0000±-1.00000; 1e-06: -1.0000±-1.00000; 1e-09: -1.0000±-1.00000; 1e-12: -1.0000±-1.00000;
#
# L0, nnz = 0.018±0.000, prec time = 0.000474±0.000027
# Residuals:   0.001: 147±4.27; 1e-06: 185±4.02; 1e-09: 217±4.04; 1e-12: 245±4.16;
# Time:        0.001: 1.0857±0.16263; 1e-06: 1.3664±0.20268; 1e-09: 1.6005±0.23695; 1e-12: 1.8038±0.26564;
#
# Lt1, nnz = 0.024±0.000, prec time = 0.003420±0.000242
# Residuals:   0.001: 89±2.63; 1e-06: 112±2.47; 1e-09: 132±2.47; 1e-12: 149±2.49;
# Time:        0.001: 0.6254±0.08375; 1e-06: 0.7877±0.10653; 1e-09: 0.9232±0.12508; 1e-12: 1.0409±0.14160;
#
# Lt5, nnz = 0.048±0.000, prec time = 0.008113±0.000563
# Residuals:   0.001: 45±1.42; 1e-06: 57±1.22; 1e-09: 68±1.24; 1e-12: 77±1.26;
# Time:        0.001: 0.4571±0.05002; 1e-06: 0.5794±0.06185; 1e-09: 0.6810±0.07299; 1e-12: 0.7707±0.08291;
#
# ------------------------------------------------------------------------------------------------
#
# ['div_k_grad', 32, 0.7]
#   Precs are combined
#   I is skipped
#   L0 is done
#   Lt1 is done
#   Lt5 is done
# I, nnz = 0.476±0.000, prec time = -1.000000±-1.000000
# Residuals:   0.001: -1±-1.00; 1e-06: -1±-1.00; 1e-09: -1±-1.00; 1e-12: -1±-1.00;
# Time:        0.001: -1.0000±-1.00000; 1e-06: -1.0000±-1.00000; 1e-09: -1.0000±-1.00000; 1e-12: -1.0000±-1.00000;
#
# L0, nnz = 0.287±0.000, prec time = 0.000074±0.000008
# Residuals:   0.001: 39±1.35; 1e-06: 49±1.40; 1e-09: 58±1.47; 1e-12: 66±1.42;
# Time:        0.001: 0.0523±0.00242; 1e-06: 0.0660±0.00268; 1e-09: 0.0776±0.00293; 1e-12: 0.0874±0.00313;
#
# Lt1, nnz = 0.378±0.000, prec time = 0.000263±0.000016
# Residuals:   0.001: 23±0.86; 1e-06: 29±0.89; 1e-09: 35±0.89; 1e-12: 40±0.93;
# Time:        0.001: 0.0286±0.00100; 1e-06: 0.0363±0.00106; 1e-09: 0.0428±0.00106; 1e-12: 0.0486±0.00112;
#
# Lt5, nnz = 0.754±0.001, prec time = 0.000597±0.000020
# Residuals:   0.001: 10±0.49; 1e-06: 14±0.38; 1e-09: 17±0.39; 1e-12: 20±0.36;
# Time:        0.001: 0.0166±0.00068; 1e-06: 0.0217±0.00054; 1e-09: 0.0259±0.00055; 1e-12: 0.0299±0.00052;
#
# ------------------------------------------------------------------------------------------------
#
# ['div_k_grad', 64, 0.7]
#   Precs are combined
#   I is skipped
#   L0 is done
#   Lt1 is done
#   Lt5 is done
# I, nnz = 0.121±0.000, prec time = -1.000000±-1.000000
# Residuals:   0.001: -1±-1.00; 1e-06: -1±-1.00; 1e-09: -1±-1.00; 1e-12: -1±-1.00;
# Time:        0.001: -1.0000±-1.00000; 1e-06: -1.0000±-1.00000; 1e-09: -1.0000±-1.00000; 1e-12: -1.0000±-1.00000;
#
# L0, nnz = 0.072±0.000, prec time = 0.000155±0.000009
# Residuals:   0.001: 77±2.86; 1e-06: 98±3.20; 1e-09: 115±3.08; 1e-12: 129±3.10;
# Time:        0.001: 0.1684±0.00611; 1e-06: 0.2123±0.00682; 1e-09: 0.2478±0.00662; 1e-12: 0.2782±0.00669;
#
# Lt1, nnz = 0.096±0.000, prec time = 0.000874±0.000024
# Residuals:   0.001: 46±1.78; 1e-06: 59±1.87; 1e-09: 69±1.86; 1e-12: 78±1.80;
# Time:        0.001: 0.1043±0.00388; 1e-06: 0.1318±0.00412; 1e-09: 0.1543±0.00412; 1e-12: 0.1737±0.00399;
#
# Lt5, nnz = 0.192±0.000, prec time = 0.002103±0.000048
# Residuals:   0.001: 22±0.78; 1e-06: 28±0.82; 1e-09: 34±0.81; 1e-12: 38±0.82;
# Time:        0.001: 0.0670±0.00248; 1e-06: 0.0852±0.00292; 1e-09: 0.1007±0.00315; 1e-12: 0.1143±0.00337;
#
# ------------------------------------------------------------------------------------------------
#
# ['div_k_grad', 128, 0.7]
#   Precs are combined
#   I is skipped
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 scipy_benchmark_all(params_grid, N=200, cg_iter=None, pcg_iter=270, atol=0)
#
# Cell In[5], line 5, in scipy_benchmark_all(params_grid, N, cg_iter, pcg_iter, atol)
#       3 print(p)
#       4 A, _, b, _, _ = dataset_qtt(pde=p[0], grid=p[1], variance=p[2], lhs_type='fd', return_train=False, N_samples=N, precision='f64')
# ----> 5 out = scipy_benchmark_linsys(A, b, cg_iter=cg_iter, pcg_iter=pcg_iter, atol=atol)
#       6 for i, name in enumerate(['I', 'L0', 'Lt1', 'Lt5']):
#       7     print_results(name, out[i])
#
# Cell In[3], line 63, in scipy_benchmark_linsys(A, b, cg_iter, pcg_iter, atol)
#      60         print('  I is skipped')
#      62     # L0
# ---> 63     _, L0_iters_mean, L0_iters_std, L0_time_mean, L0_time_std = batched_cg_scipy(A, b, P=P_L0, atol=atol, maxiter=pcg_iter)
#      64 #     res_L0_mean = list(iter_per_residual(res_ls.mean(0)).values())
#      65 #     res_L0_std = res_ls.std(0)[res_L0_mean]
#      66 #     time_L0_mean = time_ls.mean(0)[res_L0_mean]
#      67 #     time_L0_std = time_ls.std(0)[res_L0_mean]
#      68     print('  L0 is done')
#
# File /mnt/local/data/vtrifonov/prec-learning-Notay-loss/linsolve/scipy_linsolve.py:29, in batched_cg_scipy(A, b, P, atol, maxiter)
#      27     time_ls[1].append(time_i[iters_ls[1][-1]])
#      28     time_ls[2].append(time_i[iters_ls[2][-1]])
# ---> 29     time_ls[3].append(time_i[iters_ls[3][-1]])
#      31 iters_mean = [
#      32     np.mean(iters_ls[0]), np.mean(iters_ls[1]), np.mean(iters_ls[2]), np.mean(iters_ls[3])
#      33 ]
#      34 iters_std = [
#      35     np.std(iters_ls[0]), np.std(iters_ls[1]), np.std(iters_ls[2]), np.std(iters_ls[3])
#      36 ]
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
2+3

# %%
scipy_benchmark_all(params_grid, N=200, cg_iter=700, pcg_iter=270, atol=0)
# Out:
# ['poisson', 32, 0.1]
# 2024-09-21 17:40:46.087786: W external/xla/xla/service/gpu/nvptx_compiler.cc:760] The NVIDIA driver's CUDA version is 12.4 which is older than the ptxas CUDA version (12.5.40). Because the driver is older than the ptxas version, XLA is disabling parallel compilation, which may slow down compilation. You should update your NVIDIA driver or use the NVIDIA-provided CUDA forward compatibility packages.
#   Precs are combined
#   I is done
#   L0 is done
#   Lt1 is done
#   Lt5 is done
# I, nnz = 0.476±0.000, prec time = -1.000000±-1.000000
# Residuals:   0.001: 93±0.00; 1e-06: 116±0.00; 1e-09: 134±0.00; 1e-12: 150±0.00;
# Time:        0.001: 0.0092±0.06742; 1e-06: 0.0100±0.06742; 1e-09: 0.0106±0.06741; 1e-12: 0.0111±0.06741;
#
# L0, nnz = 0.287±0.000, prec time = 0.000082±0.000009
# Residuals:   0.001: 31±0.00; 1e-06: 39±0.27; 1e-09: 49±0.00; 1e-12: 55±0.00;
# Time:        0.001: 0.0409±0.00163; 1e-06: 0.0509±0.00211; 1e-09: 0.0633±0.00249; 1e-12: 0.0707±0.00277;
#
# Lt1, nnz = 0.379±0.000, prec time = 0.000302±0.000033
# Residuals:   0.001: 20±0.45; 1e-06: 25±0.00; 1e-09: 30±0.00; 1e-12: 35±0.00;
# Time:        0.001: 0.0253±0.00070; 1e-06: 0.0315±0.00056; 1e-09: 0.0373±0.00064; 1e-12: 0.0431±0.00071;
#
# Lt5, nnz = 0.758±0.000, prec time = 0.000614±0.000076
# Residuals:   0.001: 10±0.00; 1e-06: 14±0.00; 1e-09: 17±0.00; 1e-12: 20±0.00;
# Time:        0.001: 0.0161±0.00069; 1e-06: 0.0215±0.00090; 1e-09: 0.0256±0.00105; 1e-12: 0.0297±0.00119;
#
# ------------------------------------------------------------------------------------------------
#
# ['poisson', 64, 0.1]
#   Precs are combined
#   I is done
#   L0 is done
#   Lt1 is done
#   Lt5 is done
# I, nnz = 0.121±0.000, prec time = -1.000000±-1.000000
# Residuals:   0.001: 189±0.00; 1e-06: 235±0.10; 1e-09: 270±0.00; 1e-12: 301±0.00;
# Time:        0.001: 0.0170±0.07435; 1e-06: 0.0195±0.07436; 1e-09: 0.0214±0.07437; 1e-12: 0.0231±0.07438;
#
# L0, nnz = 0.072±0.000, prec time = 0.000187±0.000014
# Residuals:   0.001: 62±0.00; 1e-06: 77±0.00; 1e-09: 93±0.00; 1e-12: 108±0.18;
# Time:        0.001: 0.1338±0.00087; 1e-06: 0.1653±0.00092; 1e-09: 0.1990±0.00102; 1e-12: 0.2304±0.00116;
#
# Lt1, nnz = 0.096±0.000, prec time = 0.001104±0.000134
# Residuals:   0.001: 38±0.00; 1e-06: 50±0.00; 1e-09: 59±0.00; 1e-12: 67±0.00;
# Time:        0.001: 0.0859±0.00187; 1e-06: 0.1120±0.00243; 1e-09: 0.1317±0.00342; 1e-12: 0.1491±0.00373;
#
# Lt5, nnz = 0.193±0.000, prec time = 0.002474±0.000296
# Residuals:   0.001: 21±0.00; 1e-06: 27±0.00; 1e-09: 33±0.00; 1e-12: 38±0.00;
# Time:        0.001: 0.0638±0.00172; 1e-06: 0.0809±0.00216; 1e-09: 0.0980±0.00259; 1e-12: 0.1122±0.00295;
#
# ------------------------------------------------------------------------------------------------
#
# ['poisson', 128, 0.1]
#   Precs are combined
#   I is done
#   L0 is done
#   Lt1 is done
#   Lt5 is done
# I, nnz = 0.030±0.000, prec time = -1.000000±-1.000000
# Residuals:   0.001: 388±0.00; 1e-06: 474±0.00; 1e-09: 544±0.00; 1e-12: 601±0.00;
# Time:        0.001: 0.1295±0.05625; 1e-06: 0.1570±0.05592; 1e-09: 0.1794±0.05566; 1e-12: 0.1976±0.05546;
#
# L0, nnz = 0.018±0.000, prec time = 0.000458±0.000021
# Residuals:   0.001: 115±0.00; 1e-06: 157±0.50; 1e-09: 181±0.00; 1e-12: 212±0.00;
# Time:        0.001: 0.9001±0.11554; 1e-06: 1.2221±0.15629; 1e-09: 1.4116±0.18063; 1e-12: 1.6517±0.21103;
#
# Lt1, nnz = 0.024±0.000, prec time = 0.003282±0.000083
# Residuals:   0.001: 71±0.34; 1e-06: 98±0.00; 1e-09: 117±0.00; 1e-12: 133±0.00;
# Time:        0.001: 0.4560±0.02644; 1e-06: 0.6276±0.03661; 1e-09: 0.7477±0.04393; 1e-12: 0.8489±0.05011;
#
# Lt5, nnz = 0.048±0.000, prec time = 0.007709±0.000247
# Residuals:   0.001: 40±0.07; 1e-06: 54±0.00; 1e-09: 64±0.00; 1e-12: 73±0.00;
# Time:        0.001: 0.4219±0.06427; 1e-06: 0.5648±0.08609; 1e-09: 0.6668±0.10167; 1e-12: 0.7587±0.11567;
#
# ------------------------------------------------------------------------------------------------
#
# ['div_k_grad', 32, 0.1]
#   Precs are combined
#   I is done
#   L0 is done
#   Lt1 is done
#   Lt5 is done
# I, nnz = 0.476±0.000, prec time = -1.000000±-1.000000
# Residuals:   0.001: 126±3.69; 1e-06: 163±4.23; 1e-09: 195±4.31; 1e-12: 223±4.74;
# Time:        0.001: 0.0046±0.00069; 1e-06: 0.0056±0.00081; 1e-09: 0.0066±0.00092; 1e-12: 0.0074±0.00101;
#
# L0, nnz = 0.287±0.000, prec time = 0.000072±0.000004
# Residuals:   0.001: 32±0.62; 1e-06: 42±0.70; 1e-09: 50±0.58; 1e-12: 58±0.55;
# Time:        0.001: 0.0427±0.00119; 1e-06: 0.0550±0.00146; 1e-09: 0.0655±0.00166; 1e-12: 0.0749±0.00175;
#
# Lt1, nnz = 0.379±0.000, prec time = 0.000261±0.000013
# Residuals:   0.001: 20±0.49; 1e-06: 26±0.48; 1e-09: 31±0.47; 1e-12: 36±0.34;
# Time:        0.001: 0.0252±0.00064; 1e-06: 0.0323±0.00064; 1e-09: 0.0387±0.00066; 1e-12: 0.0442±0.00049;
#
# Lt5, nnz = 0.756±0.001, prec time = 0.000548±0.000012
# Residuals:   0.001: 10±0.22; 1e-06: 14±0.42; 1e-09: 17±0.20; 1e-12: 20±0.18;
# Time:        0.001: 0.0160±0.00033; 1e-06: 0.0212±0.00059; 1e-09: 0.0255±0.00030; 1e-12: 0.0296±0.00030;
#
# ------------------------------------------------------------------------------------------------
#
# ['div_k_grad', 64, 0.1]
#   Precs are combined
#   I is done
#   L0 is done
#   Lt1 is done
#   Lt5 is done
# I, nnz = 0.121±0.000, prec time = -1.000000±-1.000000
# Residuals:   0.001: 288±9.61; 1e-06: 370±10.59; 1e-09: 435±11.59; 1e-12: 496±13.00;
# Time:        0.001: 0.0155±0.00186; 1e-06: 0.0196±0.00227; 1e-09: 0.0229±0.00260; 1e-12: 0.0259±0.00290;
#
# L0, nnz = 0.072±0.000, prec time = 0.000155±0.000010
# Residuals:   0.001: 65±1.38; 1e-06: 84±1.04; 1e-09: 99±0.93; 1e-12: 113±0.97;
# Time:        0.001: 0.1445±0.01000; 1e-06: 0.1849±0.01222; 1e-09: 0.2176±0.01413; 1e-12: 0.2472±0.01584;
#
# Lt1, nnz = 0.096±0.000, prec time = 0.000861±0.000028
# Residuals:   0.001: 40±0.86; 1e-06: 51±0.76; 1e-09: 61±0.60; 1e-12: 69±0.67;
# Time:        0.001: 0.0893±0.00197; 1e-06: 0.1144±0.00172; 1e-09: 0.1353±0.00139; 1e-12: 0.1540±0.00147;
#
# Lt5, nnz = 0.192±0.000, prec time = 0.001933±0.000084
# Residuals:   0.001: 20±0.55; 1e-06: 27±0.36; 1e-09: 32±0.37; 1e-12: 37±0.32;
# Time:        0.001: 0.0630±0.00267; 1e-06: 0.0813±0.00290; 1e-09: 0.0961±0.00344; 1e-12: 0.1102±0.00388;
#
# ------------------------------------------------------------------------------------------------
#
# ['div_k_grad', 128, 0.1]
#   Precs are combined
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 scipy_benchmark_all(params_grid, N=200, cg_iter=700, pcg_iter=270, atol=0)
#
# Cell In[5], line 5, in scipy_benchmark_all(params_grid, N, cg_iter, pcg_iter, atol)
#       3 print(p)
#       4 A, _, b, _, _ = dataset_qtt(pde=p[0], grid=p[1], variance=p[2], lhs_type='fd', return_train=False, N_samples=N, precision='f64')
# ----> 5 out = scipy_benchmark_linsys(A, b, cg_iter=cg_iter, pcg_iter=pcg_iter, atol=atol)
#       6 for i, name in enumerate(['I', 'L0', 'Lt1', 'Lt5']):
#       7     print_results(name, out[i])
#
# Cell In[3], line 51, in scipy_benchmark_linsys(A, b, cg_iter, pcg_iter, atol)
#      47     print('  Precs are combined')
#      49     ## Run PCG
#      50     # I
# ---> 51     _, I_iters_mean, I_iters_std, I_time_mean, I_time_std = batched_cg_scipy(A, b, P=None, atol=atol, maxiter=cg_iter)
#      52 #     res_I_mean = list(iter_per_residual(res_ls.mean(0)).values())
#      53 #     res_I_std = res_ls.std(0)[res_I_mean]
#      54 #     time_I_mean = time_ls.mean(0)[res_I_mean]
#      55 #     time_I_std = time_ls.std(0)[res_I_mean]
#      56     print('  I is done')
#
# File /mnt/local/data/vtrifonov/prec-learning-Notay-loss/linsolve/scipy_linsolve.py:27, in batched_cg_scipy(A, b, P, atol, maxiter)
#      24 iters_ls[3].append(iters[1e-12])
#      26 time_ls[0].append(time_i[iters_ls[0][-1]])
# ---> 27 time_ls[1].append(time_i[iters_ls[1][-1]])
#      28 time_ls[2].append(time_i[iters_ls[2][-1]])
#      29 time_ls[3].append(time_i[iters_ls[3][-1]])
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
import numpy as np

np.array([1, 2, 3, 4, ]).mean()
# Out:
# nan

# %%
scipy_benchmark_all(params_grid, N=200, cg_iter=700, pcg_iter=270, atol=0)
# Out:
# ['poisson', 32, 0.1]
# 2024-09-19 14:46:53.161795: W external/xla/xla/service/gpu/nvptx_compiler.cc:760] The NVIDIA driver's CUDA version is 12.4 which is older than the ptxas CUDA version (12.5.40). Because the driver is older than the ptxas version, XLA is disabling parallel compilation, which may slow down compilation. You should update your NVIDIA driver or use the NVIDIA-provided CUDA forward compatibility packages.
#   Precs are combined
#   I is done
#   L0 is done
#   Lt1 is done
#   Lt5 is done
# I
# Residuals:   0.001: 93±0.00; 1e-06: 116±0.00; 1e-09: 134±0.00; 1e-12: 150±0.00;
# Time:        0.001: 0.0080±0.06500; 1e-06: 0.0086±0.06501; 1e-09: 0.0091±0.06501; 1e-12: 0.0096±0.06502;
#
# L0
# Residuals:   0.001: 31±0.00; 1e-06: 39±0.00; 1e-09: 49±0.00; 1e-12: 55±0.00;
# Time:        0.001: 0.0420±0.00024; 1e-06: 0.0522±0.00031; 1e-09: 0.0649±0.00038; 1e-12: 0.0726±0.00041;
#
# Lt1
# Residuals:   0.001: 20±0.00; 1e-06: 25±0.00; 1e-09: 30±0.00; 1e-12: 35±0.00;
# Time:        0.001: 0.0294±0.00222; 1e-06: 0.0361±0.00260; 1e-09: 0.0428±0.00298; 1e-12: 0.0495±0.00337;
#
# Lt5
# Residuals:   0.001: 10±0.00; 1e-06: 14±0.00; 1e-09: 17±0.00; 1e-12: 20±0.00;
# Time:        0.001: 0.0182±0.00138; 1e-06: 0.0245±0.00175; 1e-09: 0.0292±0.00201; 1e-12: 0.0339±0.00227;
#
# ------------------------------------------------------------------------------------------------
#
# ['poisson', 64, 0.1]
#   Precs are combined
#   I is done
#   L0 is done
#   Lt1 is done
#   Lt5 is done
# I
# Residuals:   0.001: 189±0.00; 1e-06: 235±0.00; 1e-09: 270±0.00; 1e-12: 301±0.00;
# Time:        0.001: 0.0171±0.08441; 1e-06: 0.0196±0.08447; 1e-09: 0.0214±0.08451; 1e-12: 0.0230±0.08454;
#
# L0
# Residuals:   0.001: 62±0.00; 1e-06: 77±0.00; 1e-09: 93±0.00; 1e-12: 108±0.00;
# Time:        0.001: 0.1371±0.00101; 1e-06: 0.1694±0.00125; 1e-09: 0.2039±0.00153; 1e-12: 0.2362±0.00176;
#
# Lt1
# Residuals:   0.001: 38±0.00; 1e-06: 50±0.00; 1e-09: 59±0.00; 1e-12: 67±0.00;
# Time:        0.001: 0.0949±0.00041; 1e-06: 0.1238±0.00046; 1e-09: 0.1455±0.00185; 1e-12: 0.1647±0.00186;
#
# Lt5
# Residuals:   0.001: 21±0.00; 1e-06: 27±0.00; 1e-09: 33±0.00; 1e-12: 38±0.00;
# Time:        0.001: 0.0714±0.00336; 1e-06: 0.0905±0.00422; 1e-09: 0.1096±0.00507; 1e-12: 0.1255±0.00578;
#
# ------------------------------------------------------------------------------------------------
#
# ['poisson', 128, 0.1]
#   Precs are combined
#   I is done
#   L0 is done
#   Lt1 is done
#   Lt5 is done
# I
# Residuals:   0.001: 388±0.00; 1e-06: 474±0.00; 1e-09: 544±0.00; 1e-12: 601±0.00;
# Time:        0.001: 0.1268±0.06725; 1e-06: 0.1535±0.06736; 1e-09: 0.1753±0.06747; 1e-12: 0.1931±0.06815;
#
# L0
# Residuals:   0.001: 115±0.00; 1e-06: 157±0.00; 1e-09: 181±0.00; 1e-12: 212±0.00;
# Time:        0.001: 0.9173±0.08041; 1e-06: 1.2486±0.10936; 1e-09: 1.4382±0.12616; 1e-12: 1.6826±0.14767;
#
# Lt1
# Residuals:   0.001: 71±0.00; 1e-06: 98±0.00; 1e-09: 117±0.00; 1e-12: 133±0.00;
# Time:        0.001: 0.6586±0.00127; 1e-06: 0.9049±0.00172; 1e-09: 1.0782±0.00204; 1e-12: 1.2242±0.00231;
#
# Lt5
# Residuals:   0.001: 40±0.00; 1e-06: 54±0.00; 1e-09: 64±0.00; 1e-12: 73±0.00;
# Time:        0.001: 0.4335±0.04994; 1e-06: 0.5812±0.06638; 1e-09: 0.6864±0.07810; 1e-12: 0.7810±0.08870;
#
# ------------------------------------------------------------------------------------------------
#
# ['div_k_grad', 32, 0.1]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 scipy_benchmark_all(params_grid, N=200, cg_iter=700, pcg_iter=270, atol=0)
#
# Cell In[5], line 5, in scipy_benchmark_all(params_grid, N, cg_iter, pcg_iter, atol)
#       3 print(p)
#       4 A, _, b, _, _ = dataset_qtt(pde=p[0], grid=p[1], variance=p[2], lhs_type='fd', return_train=False, N_samples=N, precision='f64')
# ----> 5 out = scipy_benchmark_linsys(A, b, cg_iter=cg_iter, pcg_iter=pcg_iter, atol=atol)
#       6 for i, name in enumerate(['I', 'L0', 'Lt1', 'Lt5']):
#       7     print_results(name, out[i])
#
# Cell In[3], line 52, in scipy_benchmark_linsys(A, b, cg_iter, pcg_iter, atol)
#      50 P_L0 = make_Chol_prec(jsparse.bcoo_concatenate(L0, dimension=0))
#      51 P_Lt1 = make_Chol_prec(jsparse.bcoo_concatenate(Lt1, dimension=0))
# ---> 52 P_Lt5 = make_Chol_prec(jsparse.bcoo_concatenate(Lt5, dimension=0))
#      53 print('  Precs are combined')
#      55 ## Run PCG
#      56 # I
#
# File /mnt/local/data/vtrifonov/prec-learning-Notay-loss/linsolve/scipy_linsolve.py:45, in make_Chol_prec(L)
#      44 def make_Chol_prec(L):
# ---> 45     return [LinearOperator(shape=L_.shape, matvec=partial(solve_precChol, L=jBCOO_to_scipyCSR(L_))) for L_ in L]
#
# File /mnt/local/data/vtrifonov/prec-learning-Notay-loss/linsolve/scipy_linsolve.py:45, in <listcomp>(.0)
#      44 def make_Chol_prec(L):
# ---> 45     return [LinearOperator(shape=L_.shape, matvec=partial(solve_precChol, L=jBCOO_to_scipyCSR(L_))) for L_ in L]
#
# File /mnt/local/data/vtrifonov/prec-learning-Notay-loss/utils.py:63, in jBCOO_to_scipyCSR(A)
#      62 def jBCOO_to_scipyCSR(A):
# ---> 63     return coo_matrix((A.data, (A.indices[:, 0], A.indices[:, 1])), shape=A.shape, dtype=np.float64).tocsr()
#
# File /usr/local/lib/python3.10/dist-packages/scipy/sparse/_coo.py:99, in _coo_base.__init__(self, arg1, shape, dtype, copy)
#      96 if dtype is not None:
#      97     self.data = self.data.astype(dtype, copy=False)
# ---> 99 self._check()
#
# File /usr/local/lib/python3.10/dist-packages/scipy/sparse/_coo.py:205, in _coo_base._check(self)
#     203 for i, idx in enumerate(self.coords):
#     204     if idx.max() >= self.shape[i]:
# --> 205         raise ValueError(f'axis {i} index {idx.max()} exceeds '
#     206                          f'matrix dimension {self.shape[i]}')
#     207     if idx.min() < 0:
#     208         raise ValueError(f'negative axis {i} index: {idx.min()}')
#
# ValueError: axis 0 index 1024 exceeds matrix dimension 1024

# %% [markdown]
# ---
#
# ---
#
# # Check number of iterations

# %%
pde = 'div_k_grad'      # 'poisson', 'div_k_grad'
grid = 64            # 32, 64, 128
variance = 1.5        # 0.1, 0.5, 1.0 1.5

# %%
s1 = perf_counter()
A, _, b, _, _ = dataset_qtt(pde, grid, variance, lhs_type='fd', return_train=False)
dt_data = perf_counter() - s1

# %%
i = 101
fill_factor = 10
threshold = 1e-4

# %%
L0 = ilupp.ichol0(jBCOO_to_scipyCSR(A[i, ...]))
print(f'IC0 NNZ(L) = {(L0.nnz*100) / (L0.shape[-1] ** 2):.3f}%')

# %%
_, res_I = ConjGrad(A[i:i+1, ...], b[i:i+1, ...], N_iter=1000, prec_func=None, seed=42)
print('CG is done')

# L = ilupp.icholt(jBCOO_to_scipyCSR(A[i, ...]), add_fill_in=fill_factor, threshold=threshold)
L = L0
prec = partial(llt_prec_trig_solve, L=jsparse.BCOO.from_scipy_sparse(L)[None, ...])
print('Prec is generated', end='\n\n')

s_prec = perf_counter()
_, res = ConjGrad(A[i:i+1, ...], b[i:i+1, ...], N_iter=1000, prec_func=prec, seed=42)
dt_cg = perf_counter() - s_prec

plt.plot(range(res_I.shape[-1]), jnp.linalg.norm(res_I, axis=1).mean(0), label="CG")
plt.plot(range(res.shape[-1]), jnp.linalg.norm(res, axis=1).mean(0), label="PCG")
plt.xlabel('Iteration')
plt.ylabel('$\|res\|$')
plt.legend()
plt.yscale('log')
plt.grid();

cg_tol = iter_per_residual(jnp.linalg.norm(res_I, axis=1).mean(0))
pcg_tol = iter_per_residual(jnp.linalg.norm(res, axis=1).mean(0))

print(f'CG: {cg_tol}')
print(f'PCG: {pcg_tol}')
print(f'NNZ(L) = {(L.nnz*100) / (L.shape[-1] ** 2):.3f}%')
